# %% [markdown]
# # Hotel Caesar

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/Caesar.png)

# %% [markdown]
# # Financial Data

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/Financials.png)

# %% [markdown]
# # Workflow

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/FlowChart.png)

# %% [markdown]
# # Pre-analysis Exploration

# %% [markdown]
# ## Histograms:

# %%
from bokeh.layouts import row
from bokeh.plotting import figure, show, output_file
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f157a2dc-74cf-42d7-95e9-e09c33c14b9b">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.charts import Histogram, output_file, show
import pandas as pd

df = pd.read_csv('TrainData.csv')

# %%
df.sort('checkins', inplace=True)

hist = Histogram(df, values='checkins', color='Year',
                 title="Checkin distribution by Year", legend='top_right')

#output_notebook("histogram_single", title="histogram_single.py example")

show(hist)
# Out:
# /Users/XinyiLu/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#     <div class="bk-root">
#         <div class="plotdiv" id="5e0044eb-cd30-42b0-837d-4c48461e6e52"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5e0044eb-cd30-42b0-837d-4c48461e6e52");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5e0044eb-cd30-42b0-837d-4c48461e6e52' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"108301d7-e92b-4bba-8eb9-567d84a400ca":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["fill_alpha","y","label","width","x","line_alpha","color","height","line_color"],"data":{"chart_index":["(326.6, 555.1]"],"color":["#df5320"],"fill_alpha":[0.6],"height":[25.0],"label":["(326.6, 555.1]"],"line_alpha":[1.0],"line_color":["black"],"width":[228.57142857142856],"x":["440.85"],"y":[12.5]}},"id":"e5ebd3bd-1628-40cf-b8dd-13ef61ac376c","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":"Checkin distribution by Year"},"id":"3f623dde-3bf5-41b9-99a8-54be3f34d7ea","type":"Title"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8c060baa-0542-4d24-8ca4-1dc4cdc1acc1","type":"Rect"},{"attributes":{"data_source":{"id":"05bfd0c4-a944-4fc6-8547-5a9df15dfba6","type":"ColumnDataSource"},"glyph":{"id":"75803b08-3c67-4556-9f02-6f91f6e2c66f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b78b77f1-f692-4b49-82e3-c841a88b0827","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6f5fa076-46bb-4f86-83ac-5065316343cd","type":"Rect"},{"attributes":{"data_source":{"id":"a8964004-33b3-4e53-a2ee-de0cec121d33","type":"ColumnDataSource"},"glyph":{"id":"943f5b2c-fd63-4cf7-8d5c-324c80d62e81","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"945fa749-c984-431c-9472-1b3601df8f29","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"818e799b-24ef-4b12-a4bc-3c53794c257c","type":"ColumnDataSource"},"glyph":{"id":"872880ca-c82d-4f98-b535-2ad253ba3cea","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"58fefb2a-9b75-4544-a5a9-29c58c13a7df","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"e514fa59-e157-4f8e-bef6-9a05fe1857c7","type":"ColumnDataSource"},"glyph":{"id":"a9e381c5-2823-40ba-930d-ffa239b025a9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7bbe10df-83b1-4ef5-b403-3c1296717fc8","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e7eff8a2-b7fa-41c6-82a6-9712ea9cf6c1","type":"Rect"},{"attributes":{"callback":null,"column_names":["fill_alpha","y","label","width","x","line_alpha","color","height","line_color"],"data":{"chart_index":["(1469.4, 1698.0]"],"color":["#df5320"],"fill_alpha":[0.6],"height":[24.0],"label":["(1469.4, 1698.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[228.57142857142844],"x":["1583.7"],"y":[12.0]}},"id":"c0c82707-a481-409e-88aa-f06edfe8fd26","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7d0c79c1-2c05-40de-a8a3-bd19afa55284","type":"Rect"},{"attributes":{"data_source":{"id":"5ef98936-a187-4953-bb0b-f9fcecf91272","type":"ColumnDataSource"},"glyph":{"id":"55743c41-85d7-4026-8aa6-da56f6741f2d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"76b87874-fe86-4b68-8fba-9ca47dab7594","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[14]</strong>&gt;</code></p>

# %%
df.sort('checkins', inplace=True)
hist = Histogram(df, values='checkins', color='Months',
                 title="Checkin distribution by Months", legend='top_right')

#output_notebook("histogram_single", title="histogram_single.py example")

show(hist)
# Out:
# /Users/XinyiLu/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#     <div class="bk-root">
#         <div class="plotdiv" id="acb8cc55-85ea-4a0f-ad7f-71dbd502cf6e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("acb8cc55-85ea-4a0f-ad7f-71dbd502cf6e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'acb8cc55-85ea-4a0f-ad7f-71dbd502cf6e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"26ca81bc-e98f-4734-97ae-4c74a4dd044f":{"roots":{"references":[{"attributes":{"data_source":{"id":"f813a3a2-0c59-49c5-abc1-91c4c7e0625f","type":"ColumnDataSource"},"glyph":{"id":"62cc5d14-bc09-415a-b69f-c18c3fe4ed19","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"55403a7b-a64b-4893-b076-4b680c468c11","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["fill_alpha","y","label","width","x","line_alpha","color","height","line_color"],"data":{"chart_index":["(1284.9, 1469.7]"],"color":["#407ee7"],"fill_alpha":[0.6],"height":[25.0],"label":["(1284.9, 1469.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[184.7777777777776],"x":["1377.3000000000002"],"y":[12.5]}},"id":"a195c5a7-6ed8-4ad2-ba5f-8f2d1185c24d","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"707b3193-9be7-4c2e-8448-709596c4fa1e","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d3ea4532-755f-435d-9dfb-8be2a7639bf3","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"02cb102f-1468-4725-8316-f76189cb2987","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1e44e664-0da7-4dcd-a4f5-7d57c332c126","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4b070690-e05f-47aa-beb5-b764a270495a","type":"Rect"},{"attributes":{"data_source":{"id":"265f5122-0a3d-4d17-82da-0e21178192ba","type":"ColumnDataSource"},"glyph":{"id":"e508681c-2b09-4945-97d2-473232a79bb7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"423562b9-5847-4dad-8f48-4cb2b861b61e","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ac816008-678b-4163-90a3-d4d90d2c25d4","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a0700c7a-a38c-4e65-88ae-54a26429474b","type":"Rect"},{"attributes":{"data_source":{"id":"67457a6e-9237-4559-8f98-6a6a9c32417d","type":"ColumnDataSource"},"glyph":{"id":"caf110e2-a1eb-419b-81af-575495607164","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"44db4a2e-de56-47b1-960a-7c2d2b506d64","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"aa43e88c-fb50-4f47-a149-1ae6b180d057","type":"ColumnDataSource"},"glyph":{"id":"9086ac12-d679-47ba-846b-dbaec826f11b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e67600a0-0173-4e71-863c-6034fb754b0b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["fill_alpha","y","label","width","x","line_alpha","color","height","line_color"],"data":{"chart_index":["(728.6, 93 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[14]</strong>&gt;</code></p>

# %%
df.sort('Days', inplace=True)
hist = Histogram(df, values='checkins', color='Days',
                 title="Checkin distribution by Year", legend='top_right')

#output_notebook("histogram_single", title="histogram_single.py example")

show(hist)
# Out:
# /Users/XinyiLu/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#     <div class="bk-root">
#         <div class="plotdiv" id="adcfc37a-36ab-4e4f-869f-10a3db367b2a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("adcfc37a-36ab-4e4f-869f-10a3db367b2a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'adcfc37a-36ab-4e4f-869f-10a3db367b2a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b73a78ef-3716-4d6c-a556-1358b6df2c4d":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["fill_alpha","y","label","width","x","line_alpha","color","height","line_color"],"data":{"chart_index":["(1938.7, 2070.3]"],"color":["#c33ff3"],"fill_alpha":[0.6],"height":[1.0],"label":["(1938.7, 2070.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[131.59090909090878],"x":["2004.5"],"y":[0.5]}},"id":"d6e69741-7b05-4d13-b687-90b345ea8174","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["fill_alpha","y","label","width","x","line_alpha","color","height","line_color"],"data":{"chart_index":["(1931.8, 2081.5]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[0.0],"label":["(1931.8, 2081.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[149.73333333333312],"x":["2006.65"],"y":[0.0]}},"id":"888294e4-f08c-4a12-8de7-c830c8f8c111","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"dc08531a-1165-4aa3-ba9c-1797b6c248bf","type":"ColumnDataSource"},"glyph":{"id":"86237d72-f0df-4296-afa8-491364c580e3","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ba9956fb-2310-48ee-9b0e-1dac0e07f49d","type":"GlyphRenderer"},{"attributes":{},"id":"a7a1b4ff-722e-4671-b4fb-7b671eeb5748","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4a0818be-009a-4cdd-8da9-7e1d59d165ff","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"09e5bedf-16f1-420e-869a-eb19016e073d","type":"Rect"},{"attributes":{"data_source":{"id":"5a64fa5a-8ec7-41b7-9c3b-c690c5323236","type":"ColumnDataSource"},"glyph":{"id":"0047bc85-1861-4498-be0a-43deb20e034c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8e42b727-d11d-4623-84c6-15de0ee766de","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"96ecc769-5034-4796-b7f2-9b75e1ac9cd6","type":"ColumnDataSource"},"glyph":{"id":"856e7d46-2164-486d-93d3-5bf5e22f365e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"79f1309f-9e32-41c5-acec-f3ca7145e091","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6160a987-8959-43b4-a243-a5245a2ef0ec","type":"Rect"},{"attributes":{"data_source":{"id":"b74db117-1694-4165-b76f-d0cdb52c3257","type":"ColumnDataSource"},"glyph":{"id":"b29718e2-9372-47e5-b325-4681729d2d0b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3a615053-7c43-47e4-98da-a62e918ceaea","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["fill_alpha","y","label","width","x","line_alpha","color","height","line_color"],"data":{"chart_index":["(1490.2, 1617.3]"],"color":["#df5320"],"fill_alpha":[0.6],"height":[29.0],"label":["(1490.2, 1617.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[127.16666666666674],"x":["1553.75"],"y":[14.5]}},"id":"8640d7b3-c414-4743-a697-cdbdea6e4308","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"8d6a4498-8aa6-4a17-93e9-ac8b7ccfc450","type":"ColumnDataSource"},"glyph":{"id":"f409533d-dfae-4241-a30e-3cfcd55eb999","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5b10075a-08bc-40b4-99cd-b22e15514231","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"7ba5e144-4cd1-4d41-aefb-8f3c2456d6cb","type":"ColumnDataSource"},"glyph":{"id":"47cec ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[14]</strong>&gt;</code></p>

# %%
df.sort('Holidays', inplace=True)
hist = Histogram(df, values='checkins', color='Holidays',
                 title="Checkin distribution by Year", legend='top_right')

#output_notebook("histogram_single", title="histogram_single.py example")

show(hist)
# Out:
# /Users/XinyiLu/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#     <div class="bk-root">
#         <div class="plotdiv" id="07fb4f96-6dfd-49f2-822a-91351fbce92e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("07fb4f96-6dfd-49f2-822a-91351fbce92e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '07fb4f96-6dfd-49f2-822a-91351fbce92e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"bb1ed183-71b0-4ce5-aa12-74e989b39bdd":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["fill_alpha","y","label","width","x","line_alpha","color","height","line_color"],"data":{"chart_index":["[638.0, 704.0]"],"color":["#407ee7"],"fill_alpha":[0.6],"height":[1.0],"label":["[638.0, 704.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[66.0],"x":["671.0"],"y":[0.5]}},"id":"15e46047-7353-4bf3-8474-432f024a461a","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8e94245d-0063-4855-a2f2-816f9e9cb64a","type":"Rect"},{"attributes":{"callback":null,"column_names":["fill_alpha","y","label","width","x","line_alpha","color","height","line_color"],"data":{"chart_index":["(2205.5, 2942.0]"],"color":["#df5320"],"fill_alpha":[0.6],"height":[2.0],"label":["(2205.5, 2942.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[736.5],"x":["2573.75"],"y":[1.0]}},"id":"fe7c6cbb-ef75-464b-842d-7f7c287a3ed7","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"159eb682-c727-4e11-bf13-e6651109eaa1","type":"Rect"},{"attributes":{"callback":null,"column_names":["fill_alpha","y","label","width","x","line_alpha","color","height","line_color"],"data":{"chart_index":["(1476.5, 1582.5]"],"color":["#407ee7"],"fill_alpha":[0.6],"height":[72.0],"label":["(1476.5, 1582.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[106.03571428571422],"x":["1529.5"],"y":[36.0]}},"id":"cf983939-c343-4edd-b5a7-f96c58c5fa8b","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6c6c9721-e59e-432c-9d3d-43244cf13ff4","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c366e94e-801c-46f4-99f3-3e53a52c9dcc","type":"Rect"},{"attributes":{"callback":null,"column_names":["fill_alpha","y","label","width","x","line_alpha","color","height","line_color"],"data":{"chart_index":["(204.0, 310.1]"],"color":["#407ee7"],"fill_alpha":[0.6],"height":[3.0],"label":["(204.0, 310.1]"],"line_alpha":[1.0],"line_color":["black"],"width":[106.03571428571428],"x":["257.05"],"y":[1.5]}},"id":"66ff4072-b605-4d6b-ba3c-8e751822eae1","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"814e105e-630e-4252-b53c-efd10c2a8f6c","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"014a578b-d2ba-4067-b332-38fec7a0f9f7","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b46c8302-b019-414f-82c0-92ed80098ac9","type":"Rect"},{"attributes":{"data_source":{"id":"5f0d83f0-e1b9-420c-a5ee-7d80b2174d7a","type":"ColumnDataSource"},"glyph":{"id":"94e49df6-1c01-433e-aa00-c11197bef299","type":"R ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[14]</strong>&gt;</code></p>

# %% [markdown]
# ## Box plots:

# %%
dfmv = pd.read_csv('/Users/XinyiLu/Documents/Programming/Project/TrainDataNew.csv',header = 0, na_values = 'NA')

# %%
headers = df.dtypes.index

# %%
from bokeh.charts import BoxPlot, output_file, show
from bokeh.layouts import row
#from bokeh.sampledata.autompg import autompg as df

# origin = the source of the data that makes up the autompg dataset


# color by one dimension and label by two dimensions
# coloring by one of the columns visually groups them together

box = BoxPlot(dfmv, values='checkins', label='Jan', plot_width=200, plot_height=200 , color='Jan')
box1 = BoxPlot(dfmv, values='checkins', label='Nov', plot_width=200, plot_height=200 ,color='Nov')
box2 = BoxPlot(dfmv, values='checkins', label='Sun', plot_width=200, plot_height=200 ,color='Sun' )
box3 = BoxPlot(dfmv, values='checkins', label='Fri', plot_width=200, plot_height=200 ,color='Fri' )
box4 = BoxPlot(dfmv, values='checkins', label='Xmas', plot_width=200, plot_height=200 ,color='Xmas' )
box5 = BoxPlot(dfmv, values='checkins', label='Valentines', plot_width=200, plot_height=200 ,color='Valentines' )



#output_file('box.html')
show(row(box,box1,box2,box3,box4,box5))
#output_file("boxplot_single.html", title="boxplot_single.py example")

#show(box)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f280b419-e139-4887-b686-f061eea2b587"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f280b419-e139-4887-b686-f061eea2b587");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f280b419-e139-4887-b686-f061eea2b587' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"84c4fc80-ced7-4153-b17d-781c759f5861":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f33dd996-1f57-4204-a39c-3a86e002cde8","type":"Rect"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"006d0ec2-cffb-45f5-83c0-b145c5aa04f1","type":"Circle"},{"attributes":{"data_source":{"id":"96590ca8-d63f-494e-b517-fd5dc6e074f8","type":"ColumnDataSource"},"glyph":{"id":"79594d93-97e2-478d-b6b8-ce4409e153c2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4e2f4573-d8e9-4423-b6bd-7766651c8231","type":"GlyphRenderer"},{"attributes":{"axis_label":"Fri","formatter":{"id":"beee6e45-40c0-42cf-ac6f-f23365188c7c","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"7b7db456-4a34-4758-b843-8166a53f98bf","subtype":"Chart","type":"Plot"},"ticker":{"id":"c485e4d6-767f-464b-b99b-992eaf13536f","type":"CategoricalTicker"}},"id":"31ee1b2f-b711-4602-a7e1-19b7c899da47","type":"CategoricalAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"78ec875d-19cc-436b-8214-0652c8ece962","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"9d228ee9-17af-420b-8df6-e3ca36f9430b","type":"ColumnDataSource"},"glyph":{"id":"7408fcc8-4540-4f00-9a4e-dcfd13cb1229","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cc544829-8c3a-4a14-957d-47b60ec64cc0","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"a0af1afc-e2c5-4d7a-b73a-e8f000c9d1f7","type":"Circle"},{"attributes":{},"id":"5d676618-f12d-4050-b771-f045d547327f","type":"ToolEvents"},{"attributes":{"data_source":{"id":"ed249f71-abec-4f2a-8109-302d0f4dbb50","type":"ColumnDataSource"},"glyph":{"id":"d3956989-09a0-47cf-bc31-660bbb305f66","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cca56e88-7300-4f72-85d2-d9be37d786c4","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"dcfcb09b-48af-496f-851d-81f03031c0b5","type":"ColumnDataSource"},"glyph":{"id":"ad585bc4-191f-47ff-81d8-5704efd8528f","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5dea77ba-6ed2-483b-8983-e47879b79f80","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"50231e64-0351-41d8-ae65-f2c3bc16b6a4","type":"ColumnDataSource"},"glyph":{"id":"dd6e0488-4c49-4308-bbe9-7cb258e74a15","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e6c1f79f-8e37-4466-867c-77ece68b4802","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":null},"id":"fa5d89e3-7dd6-417e-b7fc-3b78f0c84111","type":"Title"},{"attributes":{"callback":null,"column_names":["fill_alpha","y","label","width","x","line_alpha","color","height","line_color"],"data":{"Jan":[1],"chart_index":[{"Jan":1}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[202.25],"label":[{"Jan":1}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["1"],"y":[980.875]}},"id":"6701bf71-0ca9-4f0a-bc56-b32dfa1f583d","type":"ColumnDataSource"},{"attributes":{},"id":"812af4a0-cdef-4b49-8dbc-81e1097cdb81","type":"CategoricalTickFormatter"},{"attributes":{"callback":null,"end":3467.8},"id":"c8f7a537-68d1-4711-bbb6-23cf7ca7cd59","type":"Range ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[14]</strong>&gt;</code></p>

# %% [markdown]
# ## Multivariate:

# %%
from __future__ import print_function

from bokeh.document import Document
from bokeh.embed import file_html
from bokeh.layouts import gridplot
from bokeh.models.glyphs import Circle
from bokeh.models import (BasicTicker, ColumnDataSource, Grid, LinearAxis,
                         DataRange1d, PanTool, Plot, WheelZoomTool)
from bokeh.resources import INLINE
from bokeh.sampledata.iris import flowers
from bokeh.util.browser import view

colormap = {1: 'red', 0: 'green'}

dfmv['checkins'] = dfmv['JewishHoliday'].map(lambda x: colormap[x])


source = ColumnDataSource(
    data=dict(
        RewardsCardholder=dfmv['RewardsCardholder'],
        SpecialEventCustomer=dfmv['SpecialEventCustomer'],
        FreeAndIndependentTraveler=dfmv['FreeAndIndependentTraveler'],
        WholeSaleCustomer=dfmv['RewardsCardholder'],
        GroupMemberCustomer=dfmv['GroupMemberCustomer'],
        AvgRoomRateFofIndepedentTraveler=dfmv['AvgRoomRateFofIndepedentTraveler'],
        checkins=dfmv['checkins'],
    )
)

xdr = DataRange1d(bounds=None)
ydr = DataRange1d(bounds=None)

def make_plot(xname, yname, xax=False, yax=False):
    mbl = 40 if yax else 0
    mbb = 40 if xax else 0
    plot = Plot(
        x_range=xdr, y_range=ydr, background_fill_color="#efe8e2",
        border_fill_color='white', plot_width=200 + mbl, plot_height=200 + mbb,
        min_border_left=2+mbl, min_border_right=2, min_border_top=2, min_border_bottom=2+mbb)

    circle = Circle(x=xname, y=yname, fill_color="checkins", fill_alpha=0.2, size=4, line_color="checkins")
    r = plot.add_glyph(source, circle)

    xdr.renderers.append(r)
    ydr.renderers.append(r)

    xticker = BasicTicker()
    if xax:
        xaxis = LinearAxis()
        plot.add_layout(xaxis, 'below')
        xticker = xaxis.ticker
    plot.add_layout(Grid(dimension=0, ticker=xticker))

    yticker = BasicTicker()
    if yax:
        yaxis = LinearAxis()
        plot.add_layout(yaxis, 'left')
        yticker = yaxis.ticker
    plot.add_layout(Grid(dimension=1, ticker=yticker))

    plot.add_tools(PanTool(), WheelZoomTool())

    return plot

xattrs = ["RewardsCardholder","SpecialEventCustomer","FreeAndIndependentTraveler","RewardsCardholder","GroupMemberCustomer","AvgRoomRateFofIndepedentTraveler"]
yattrs = list(reversed(xattrs))
plots = []

for y in yattrs:
    row = []
    for x in xattrs:
        xax = (y == yattrs[-1])
        yax = (x == xattrs[0])
        plot = make_plot(x, y, xax, yax)
        row.append(plot)
    plots.append(row)

grid = gridplot(plots)

doc = Document()
doc.add_root(grid)

if __name__ == "__main__":
    doc.validate()
    filename = "iris_splom.html"
    with open(filename, "w") as f:
        f.write(file_html(doc, INLINE, "Iris Data SPLOM"))
    print("Wrote %s" % filename)
    view(filename)
# Out:
# Wrote iris_splom.html

# %% [markdown]
# # Dotplot:

# %% [markdown]
# Explore the coefficients fo each of the independent variables

# %%
factors = ["X1st.of.Month",
"X15th.of.Month",
"JewishHoliday",
"CNY15Days",
"CNY7Days",
"ChineseNewYear",
"SuperBowl",
"Valentines",
"Halloween",
"NewYear'sDay",
"MartinLutherKingDay",
"Pres.Day",
"Easter",
"Memorial",
"MotherDay",
"FatherDay",
"July.4th",
"LaborDay",
"ColumbusDay",
"VeteransDay",
"ThxGiving",
"Xmas",
"LongWKend",
"Jan",
"Feb",
"Mar",
"Apr",
"May",
"Jun",
"Jul",
"Aug",
"Sep",
"Oct",
"Nov",
"Sun",
"Mon",
"Tue",
"Wed",
"Thu",
"Fri",
"RewardsCardholder",
"SpecialEventCustomer",
"FreeAndIndependentTraveler",
"WholeSaleCustomer",
"GroupMemberCustomer",
"AvgRoomRateFofIndepedentTraveler"]

x =  [70.09011589,
154.3671354,
13.44997604,
7.22065767,
147.1746085,
21.77346785,
-771.2636539,
-434.3927166,
-374.9450608,
-515.7056398,
1040.608809,
1445.769212,
-145.6067709,
347.0164622,
-25.95016057,
-48.66063418,
-270.7105155,
136.8744036,
73.41669628,
169.3185561,
213.2460654,
-250.1389057,
-174.336851,
32.26334937,
81.78795756,
37.47574626,
99.73011693,
62.85859928,
-12.10380021,
11.25824005,
55.81321054,
52.24021755,
110.3417472,
41.48314857,
576.5211521,
300.2571907,
104.8750951,
149.4442819,
257.7485607,
581.0283683,
0.32981387,
0.134047735,
0.409743303,
0.026037363,
0.232772691,
-0.358254948]

dot = figure(title="Categorical Dot Plot", tools="", toolbar_location=None,
            y_range=factors, x_range=[-800,1500])

dot.segment(0, factors, x, factors, line_width=2, line_color="green", )
dot.circle(x, factors, size=15, fill_color="orange", line_color="green", line_width=3, )

factors = ["foo", "bar", "baz"]
x = ["foo", "foo", "foo", "bar", "bar", "bar", "baz", "baz", "baz"]
y = ["foo", "bar", "baz", "foo", "bar", "baz", "foo", "bar", "baz"]
colors = [
    "#0B486B", "#79BD9A", "#CFF09E",
    "#79BD9A", "#0B486B", "#79BD9A",
    "#CFF09E", "#79BD9A", "#0B486B"
]

hm = figure(title="Categorical Heatmap", tools="hover", toolbar_location=None,
            x_range=factors, y_range=factors)
hm.rect(x, y, color=colors, width=1, height=1)

#output_file("categorical.html", title="categorical.py example")

show(row(dot, sizing_mode="scale_width"))  # open a browser
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="9a7ce5a7-41da-4abb-b149-c306ed38970a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9a7ce5a7-41da-4abb-b149-c306ed38970a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9a7ce5a7-41da-4abb-b149-c306ed38970a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d250064a-4fcc-4014-8e94-8e55d1660a15":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"c58c0eb0-08f2-4716-8b16-b10036d3abb1","subtype":"Figure","type":"Plot"},"ticker":{"id":"9ccb04e2-db6f-4808-924a-9945ba777906","type":"CategoricalTicker"}},"id":"176d214d-1f80-4bcc-aed0-df5553152bdc","type":"Grid"},{"attributes":{"callback":null,"factors":["X1st.of.Month","X15th.of.Month","JewishHoliday","CNY15Days","CNY7Days","ChineseNewYear","SuperBowl","Valentines","Halloween","NewYear'sDay","MartinLutherKingDay","Pres.Day","Easter","Memorial","MotherDay","FatherDay","July.4th","LaborDay","ColumbusDay","VeteransDay","ThxGiving","Xmas","LongWKend","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Sun","Mon","Tue","Wed","Thu","Fri","RewardsCardholder","SpecialEventCustomer","FreeAndIndependentTraveler","WholeSaleCustomer","GroupMemberCustomer","AvgRoomRateFofIndepedentTraveler"]},"id":"622513ac-dd98-4556-8be0-21268260fba1","type":"FactorRange"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x0":{"value":0},"x1":{"field":"x1"},"y0":{"field":"y0"},"y1":{"field":"y1"}},"id":"7c2711e3-ec57-47a3-b6e0-5bd4d628ace7","type":"Segment"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"size":{"units":"screen","value":15},"x":{"field":"x"},"y":{"field":"y"}},"id":"a08aa07d-2675-4dc1-a1af-0fd54ffcf103","type":"Circle"},{"attributes":{"fill_color":{"value":"orange"},"line_color":{"value":"green"},"line_width":{"value":3},"size":{"units":"screen","value":15},"x":{"field":"x"},"y":{"field":"y"}},"id":"0285c4fe-9c54-4253-8739-a4009e7b812b","type":"Circle"},{"attributes":{},"id":"43789b13-546a-423a-9c50-f65e1a50cb3f","type":"ToolEvents"},{"attributes":{},"id":"b2d5d665-321a-4c20-aeed-3b2fa3f0f3ce","type":"CategoricalTickFormatter"},{"attributes":{"line_color":{"value":"green"},"line_width":{"value":2},"x0":{"value":0},"x1":{"field":"x1"},"y0":{"field":"y0"},"y1":{"field":"y1"}},"id":"d5df6a7a-b9c4-4664-8a87-d55bccde6a6d","type":"Segment"},{"attributes":{},"id":"6d6744d9-5f80-4af5-b107-37e2f248d632","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"6d6744d9-5f80-4af5-b107-37e2f248d632","type":"BasicTickFormatter"},"plot":{"id":"c58c0eb0-08f2-4716-8b16-b10036d3abb1","subtype":"Figure","type":"Plot"},"ticker":{"id":"f4b1a72b-a94f-470a-a51a-7408b7657680","type":"BasicTicker"}},"id":"0608234c-d37d-4fce-a2de-648234abe63d","type":"LinearAxis"},{"attributes":{"data_source":{"id":"017859e6-b27c-4e5b-a7ea-8b21e7d5805f","type":"ColumnDataSource"},"glyph":{"id":"d5df6a7a-b9c4-4664-8a87-d55bccde6a6d","type":"Segment"},"hover_glyph":null,"nonselection_glyph":{"id":"7c2711e3-ec57-47a3-b6e0-5bd4d628ace7","type":"Segment"},"selection_glyph":null},"id":"fd7bc8eb-1ee1-44dc-8bf0-853852512668","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":1500,"start":-800},"id":"e0e83340-9726-4a97-ba27-d438b95366ba","type":"Range1d"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[70.09011589,154.3671354,13.44997604,7.22065767,147.1746085,21.77346785,-771.2636539,-434.3927166,-374.9450608,-515.7056398,1040.608809,1445.769212,-145.6067709,347.0164622,-25.95016057,-48.66063418,-270.7105155,136.8744036,73.41669628,169.3185561,213.2460654,-250.1389057,-174.336851,32.26334937,81.78795756,37.47574626,99.73011693,62.85859928,-12.10380021,11.25824005,55.81321054,52.24021755,110.3417472,41.48314857,576.5211521,300.2571907,104.8750951,149.4442819,257.7485607,581.0283683,0.32981387,0.134047735,0.409743303,0.026037363,0.232772691,-0.358254948],"y":["X1st.of.Month","X15th.of.Month","JewishHoliday","CNY15Days","CNY7Days","ChineseNewYear","SuperBowl","Valentines","Halloween","NewYear'sDay","MartinLutherKingDay","Pres.Day","Easter","Memorial","MotherDay","FatherDay","July.4th","LaborDay","ColumbusDay","VeteransDay","ThxGiving","Xmas","L ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[14]</strong>&gt;</code></p>

# %% [markdown]
# # Forecasts：

# %%
import csv
import pandas as pd
import scipy

# %%
df = pd.read_csv('ForecastDataNew.csv')
df
# Out:
#               Date  ActualCheckins  Predicted-MA  Predicted-Reg
# 0      1/1/10 0:00             650             0     812.515115
# 1      1/2/10 0:00            1028             0     641.811214
# 2      1/3/10 0:00             944             0    1131.799437
# 3      1/4/10 0:00            1086             0     981.261214
# 4      1/5/10 0:00            1071             0     850.613456
# 5      1/6/10 0:00            1498             0    1025.782802
# 6      1/7/10 0:00             977             0    1079.030033
# 7      1/8/10 0:00             899             0    1448.109028
# 8      1/9/10 0:00             801             0     924.140511
# 9     1/10/10 0:00            1020             0    1384.140412
# 10    1/11/10 0:00            1018             0    1030.908652
# 11    1/12/10 0:00             958             0     921.132923
# 12    1/13/10 0:00             800             0     921.122098
# 13    1/14/10 0:00            1151             0    1015.347514
# 14    1/15/10 0:00            1825             0    1638.160146
# 15    1/16/10 0:00             814             0     728.107363
# 16    1/17/10 0:00            1029             0    1272.681115
# 17    1/18/10 0:00            1457             0    1862.393691
# 18    1/19/10 0:00            1080             0     838.211926
# 19    1/20/10 0:00             634             0     907.990528
# 20    1/21/10 0:00             853             0     951.953426
# 21    1/22/10 0:00            1338          1125    1378.414937
# 22    1/23/10 0:00            1181           881     849.226773
# 23    1/24/10 0:00            1495           998    1510.641591
# 24    1/25/10 0:00             583          1187    1076.550932
# 25    1/26/10 0:00             740          1036     922.170017
# 26    1/27/10 0:00            1000           977     848.493971
# 27    1/28/10 0:00            1341           994    1077.896352
# 28    1/29/10 0:00            1381          1354    1466.499111
# 29    1/30/10 0:00             714           932     882.386747
# ...            ...             ...           ...            ...
# 1307  7/31/13 0:00             300           631     824.566080
# 1308   8/1/13 0:00             393           406    1114.180180
# 1309   8/2/13 0:00            1917          1791            NaN
# 1310   8/3/13 0:00            1067          1121            NaN
# 1311   8/4/13 0:00            1598          1505            NaN
# 1312   8/5/13 0:00            1343          1088            NaN
# 1313   8/6/13 0:00             949          1264            NaN
# 1314   8/7/13 0:00            1040           669            NaN
# 1315   8/8/13 0:00             519           453            NaN
# 1316   8/9/13 0:00            1531          1771            NaN
# 1317  8/10/13 0:00            1427          1016            NaN
# 1318  8/11/13 0:00            1430          1456            NaN
# 1319  8/12/13 0:00            1053          1015            NaN
# 1320  8/13/13 0:00            1124          1291            NaN
# 1321  8/14/13 0:00            1101           629            NaN
# 1322  8/15/13 0:00             610           451            NaN
# 1323  8/16/13 0:00            1845          1716            NaN
# 1324  8/17/13 0:00            1090           950            NaN
# 1325  8/18/13 0:00            2035          1450            NaN
# 1326  8/19/13 0:00             809           937            NaN
# 1327  8/20/13 0:00             450          1381            NaN
# 1328  8/21/13 0:00             478           533            NaN
# 1329  8/22/13 0:00             511           432            NaN
# 1330  8/23/13 0:00            1955          1759            NaN
# 1331  8/24/13 0:00            1001          1029            NaN
# 1332  8/25/13 0:00            1775          1470            NaN
# 1333  8/26/13 0:00            1068          1013            NaN
# 1334  8/27/13 0:00             769          1312            NaN
# 1335  8/28/13 0:00             887           610            NaN
# 1336  8/29/13 0:00             517           445            NaN
#
# [1337 rows x 4 columns]

# %%
# !pwd
# Out:
# /Users/XinyiLu/Documents/Programming/Project

# %%
from IPython.display import Image
PATH = "/Users/XinyiLu/Documents/Programming/Project/"

# %% [markdown]
# # Prediction from Moving Average Method and the Actual values：

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/ActualAndMA.png)

# %% [markdown]
# # Prediction from Regression Method and the Actual values：

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/ActualAndReg.png)

# %%
df.Date = pd.to_datetime(df['Date'], format='%m/%d/%y %H:%M')
df.set_index(['Date'],inplace=True)
df.plot()

# %% [markdown]
# From the graph we can see that the regression model fits better than the moving average model.

# %% [markdown]
# Smaller MAPE for Regression and less Maximum error compared to Moving Average .

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/MAPE.png)
