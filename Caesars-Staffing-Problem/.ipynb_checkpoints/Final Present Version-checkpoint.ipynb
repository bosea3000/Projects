# %% [markdown]
# # Hotel Caesar

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/Caesar.png)

# %% [markdown]
# # Financial Data

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/Financials.png)

# %% [markdown]
# # Workflow

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/FlowChart.png)

# %% [markdown]
# # Pre-analysis Exploration

# %% [markdown]
# ## Histograms:

# %%
from bokeh.layouts import row
from bokeh.plotting import figure, show, output_file
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5fa04ff1-0586-4d00-bede-af622d6193e5">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.charts import Histogram, output_file, show
import pandas as pd

df = pd.read_csv('TrainData.csv')

# %%
df.sort('checkins')

hist = Histogram(df, values='Year', color='Year',
                 title="Checkin distribution by Year", legend='top_right')

#output_notebook("histogram_single", title="histogram_single.py example")

show(hist)
# Out:
# /Users/Bose/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#     <div class="bk-root">
#         <div class="plotdiv" id="c5380dc1-91db-46f0-a444-99346b421762"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c5380dc1-91db-46f0-a444-99346b421762").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c5380dc1-91db-46f0-a444-99346b421762");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c5380dc1-91db-46f0-a444-99346b421762' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8e9ca748-20c2-4436-a932-d1e5727ad551":{"roots":{"references":[{"attributes":{"label":{"value":"2013"},"renderers":[{"id":"e0e206b1-cc3b-4c92-bcc0-ed9633628db4","type":"GlyphRenderer"},{"id":"3ab20294-c3af-4c8f-bc62-ca0417500d5d","type":"GlyphRenderer"},{"id":"00bb7771-57ea-4dbe-9bec-33fc90a14e96","type":"GlyphRenderer"}]},"id":"77a68ace-1d17-43bb-a2a7-591348fc4560","type":"LegendItem"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5ce0b527-4aab-49a2-aa16-73f0241b2b78","type":"Rect"},{"attributes":{"callback":null,"column_names":["width","line_color","color","line_alpha","height","y","label","fill_alpha","x"],"data":{"chart_index":["(2012.8, 2013.2]"],"color":["#df5320"],"fill_alpha":[0.6],"height":[213.0],"label":["(2012.8, 2013.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.3333333333334849],"x":["2013.0"],"y":[106.5]}},"id":"5e632c65-76a0-4501-aff9-c3d97f0dc3b2","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":2114.0916666666662,"start":1908.9083333333335},"id":"b031e222-dd9b-40e3-832f-d8df5d68574e","type":"Range1d"},{"attributes":{"callback":null,"column_names":["width","line_color","color","line_alpha","height","y","label","fill_alpha","x"],"data":{"chart_index":["[2009.5, 2009.8]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[0.0],"label":["[2009.5, 2009.8]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.33333333333325754],"x":["2009.65"],"y":[0.0]}},"id":"bd04cd7a-f4f3-4275-8664-1260446fc294","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"40e9a38f-2fe8-4b8a-9ae5-a437b1a0dcd4","type":"Rect"},{"attributes":{"data_source":{"id":"a792a0fa-1c95-49ae-bfdc-7a9572404835","type":"ColumnDataSource"},"glyph":{"id":"24a0003c-6687-4c25-b253-c0cb61114c6f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4a104dfe-13bd-49f8-abf7-ebd7347ed26d","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["width","line_color","color","line_alpha","height","y","label","fill_alpha","x"],"data":{"chart_index":["(2011.8, 2012.2]"],"color":["#407ee7"],"fill_alpha":[0.6],"height":[371.0],"label":["(2011.8, 2012.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.3333333333334849],"x":["2012.0"],"y":[185.5]}},"id":"9ddf9b73-f231-4ca7-b8ee-7bac1de84476","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["width","line_color","color","line_alpha","height","y","label","fill_alpha","x"],"data":{"chart_index":["(2013.2, 2013.5]"],"color":["#df5320"],"fill_alpha":[0.6],"height":[0.0],"label":["(2013.2, 2013.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.33333333333325754],"x":["2013.35"],"y":[0.0]}},"id":"002f27ff-9123-4a72-a11e-faebd3e73ae6","type":"ColumnDataSource"},{"attributes":{"axis_label":"Count( Year )","formatter":{"id":"9363a22f-3cfa-41d1-a2fe-752f6330245f","type":"BasicTickFormatter"},"plot":{"id":"2cf0fa5d-c914-4a6d-9947-f82ab2ff0d1a","subtype":"Chart","type":"Plot"},"ticker":{"id":"89850a93-1e5b-4fff-afba-ba738f17ea9d","type":"BasicTicker"}},"id":"8056e846-4eea-4e7d-ade3-40414259b62c","type":"LinearAxis"},{"attributes":{"data_source":{"id":"7cccf4f5-8efe-467d-9954-de0aac98c79a","type":"ColumnDataSource"},"glyph":{"id":"93245b42-c641-4f02-a00c-0edeb3acd401","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6622ba06-742d-4e32-9bf6-14dba4c983c0","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"2cf0fa5d-c914-4a6d-9947-f82ab2ff0d1a","subtype":"Chart","type":"Plot"}},"id":"d004cd8f-9dad-4794-81d6-c48783405c54","type":"WheelZoomTool ...

# %%
df.sort('checkins')
hist = Histogram(df, values='Months-INT', color='Months-INT',
                 title="Checkin distribution by Months", legend='top_right')

#output_notebook("histogram_single", title="histogram_single.py example")

show(hist)
# Out:
# /Users/Bose/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#     <div class="bk-root">
#         <div class="plotdiv" id="c0f15d5a-f1ca-4cfe-89f9-c3b8ba851893"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c0f15d5a-f1ca-4cfe-89f9-c3b8ba851893").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c0f15d5a-f1ca-4cfe-89f9-c3b8ba851893");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c0f15d5a-f1ca-4cfe-89f9-c3b8ba851893' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8af34b29-c324-4138-8b66-d2062bd62931":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a1b4cc64-dbf8-4668-8858-3df361d5b6f3","type":"Rect"},{"attributes":{"label":{"value":"3"},"renderers":[{"id":"90ac3439-7c66-4b63-b13d-e09c5648c948","type":"GlyphRenderer"},{"id":"c15649c0-9a1b-4d51-bd03-04173871b107","type":"GlyphRenderer"},{"id":"ee11823c-f3aa-4594-850c-8d6a3bef57e0","type":"GlyphRenderer"}]},"id":"213a7406-034b-4c68-88f2-0b651ead9f20","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["width","line_color","color","line_alpha","height","y","label","fill_alpha","x"],"data":{"chart_index":["(6.8, 7.2]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[124.0],"label":["(6.8, 7.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.3333333333333339],"x":["7.0"],"y":[62.0]}},"id":"a63507b1-9e9d-472b-95ae-5f09264b8752","type":"ColumnDataSource"},{"attributes":{"label":{"value":"11"},"renderers":[{"id":"e378e5e5-1618-441d-b56c-93ab319b0d45","type":"GlyphRenderer"},{"id":"a40eced8-3ae9-45a3-a7b5-9c932092b617","type":"GlyphRenderer"},{"id":"9e96ae3f-ff29-41eb-b84d-b66aa4252076","type":"GlyphRenderer"}]},"id":"76e9cc74-f459-40be-8993-8fde021ca4ef","type":"LegendItem"},{"attributes":{},"id":"2d8da849-4a8e-4fc9-8f35-08849295fc85","type":"ToolEvents"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"88e5b6da-e3c7-4f31-a5c7-f8743dbf30c2","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6ebd2a3a-3138-4db6-acf4-8374d8653f0c","type":"Rect"},{"attributes":{"plot":{"id":"01fb459d-c06d-408c-979a-0d57811f6f4c","subtype":"Chart","type":"Plot"}},"id":"abfbe916-f25b-4957-8410-52064cff9c53","type":"SaveTool"},{"attributes":{"label":{"value":"4"},"renderers":[{"id":"5364783e-d8d4-4413-be1e-c0ad31873136","type":"GlyphRenderer"},{"id":"5daa35dc-68f8-456a-a147-64fdc88af287","type":"GlyphRenderer"},{"id":"f70d3c1e-3b4e-4b07-b249-f5263dbc76ea","type":"GlyphRenderer"}]},"id":"d2aa0091-05e2-41b8-84a9-ef0570f81231","type":"LegendItem"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"68a6996d-d134-4103-82f6-be0a4966bdf8","type":"Rect"},{"attributes":{"callback":null,"column_names":["width","line_color","color","line_alpha","height","y","label","fill_alpha","x"],"data":{"chart_index":["[2.5, 2.8]"],"color":["#407ee7"],"fill_alpha":[0.6],"height":[0.0],"label":["[2.5, 2.8]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.3333333333333335],"x":["2.65"],"y":[0.0]}},"id":"34e01536-fed3-4ff5-a6a4-95cb445593ed","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d3367a73-d2ef-4e05-adf1-e45ba0debb9d","type":"ColumnDataSource"},"glyph":{"id":"90a2ac12-1f9d-4b1f-b239-81b94ca08612","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e16128d6-320c-4618-8446-5169b9abad9d","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["width","line_color","color","line_alpha","height","y","label","fill_alpha","x"],"data":{"chart_index":["(5.2, 5.5]"],"color":["#00ad9c"],"fill_alpha":[0.6],"height":[0.0],"label":["(5.2, 5.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.33333333333333304],"x":["5.35"],"y":[0.0]}},"id":"e8ab1373-ae93-40a6-9b6f-6f ...

# %%
df.sort('checkins', inplace=True)
hist = Histogram(df, values='Days-INT', color='Days-INT',
                 title="Checkin distribution by Year", legend='top_right')

#output_notebook("histogram_single", title="histogram_single.py example")

show(hist)
# Out:
# /Users/Bose/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#     <div class="bk-root">
#         <div class="plotdiv" id="1e2a6d5f-be3b-4d3a-9410-95269b5fdc33"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#1e2a6d5f-be3b-4d3a-9410-95269b5fdc33").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1e2a6d5f-be3b-4d3a-9410-95269b5fdc33");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1e2a6d5f-be3b-4d3a-9410-95269b5fdc33' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"47a9683d-a9c4-4f4c-b31e-ad355f1d33e2":{"roots":{"references":[{"attributes":{"label":{"value":"6"},"renderers":[{"id":"dc221a67-409c-4459-b34c-46a61f543072","type":"GlyphRenderer"},{"id":"41c5445a-bd79-433a-b1db-623b2683eb26","type":"GlyphRenderer"},{"id":"9ae9abe1-c56c-4721-a56f-50feb27a3040","type":"GlyphRenderer"}]},"id":"08db97ff-bb73-47ab-b776-876b036132cb","type":"LegendItem"},{"attributes":{"data_source":{"id":"014b9824-d7e1-4dc9-85ea-2f740508f938","type":"ColumnDataSource"},"glyph":{"id":"934eaa7c-df22-4506-8848-63544f114e4f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5f80d306-94fd-43a2-85c7-57eb0a8e61e0","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"f7be4399-9015-4d05-a8a7-e4a2f1e3b207","subtype":"Chart","type":"Plot"},"ticker":{"id":"1c9c57f9-ccd1-45c3-931e-69e2b1d49597","type":"BasicTicker"}},"id":"123fb7ba-24f2-4c93-89b3-9a2f38a6fde1","type":"Grid"},{"attributes":{"overlay":{"id":"aaf1ad1a-9fbd-4f78-8855-7715be0d240a","type":"BoxAnnotation"},"plot":{"id":"f7be4399-9015-4d05-a8a7-e4a2f1e3b207","subtype":"Chart","type":"Plot"}},"id":"25f12999-025b-4166-9035-6045ee5a5e6f","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4e0a18f9-0585-4b98-8a28-dffa338e750b","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7e2d84f9-336c-4cd7-95d9-e05c6c718619","type":"Rect"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"aaf1ad1a-9fbd-4f78-8855-7715be0d240a","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3674e870-1aee-46c5-908f-2332cd7aefd5","type":"Rect"},{"attributes":{"callback":null,"column_names":["width","line_color","color","line_alpha","height","y","label","fill_alpha","x"],"data":{"chart_index":["[2.5, 2.8]"],"color":["#407ee7"],"fill_alpha":[0.6],"height":[0.0],"label":["[2.5, 2.8]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.3333333333333335],"x":["2.65"],"y":[0.0]}},"id":"0ab397d5-6baa-4764-b058-06f6f1bc99f4","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"0ab397d5-6baa-4764-b058-06f6f1bc99f4","type":"ColumnDataSource"},"glyph":{"id":"4bb4942d-fc95-4f45-a7f5-c9971ef167ec","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2221c2cc-fd30-409d-a596-ba20eaad8a6b","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"3f3ed752-0e86-48d6-bd7b-ed0bf924a7cb","type":"LinearAxis"}],"left":[{"id":"e5f39ffa-1742-40fc-bba7-947c9aa7b476","type":"LinearAxis"}],"renderers":[{"id":"aaf1ad1a-9fbd-4f78-8855-7715be0d240a","type":"BoxAnnotation"},{"id":"534b5753-0e4b-43f7-8c48-b3d0a5337ed1","type":"GlyphRenderer"},{"id":"4a072fb9-3ad5-457d-9e40-68d8a5b0bc41","type":"GlyphRenderer"},{"id":"046c9c8c-c2cf-472b-a091-8ea46a287ddb","type":"GlyphRenderer"},{"id":"2221c2cc-fd30-409d-a596-ba20eaad8a6b","type":"GlyphRenderer"},{"id":"759d491e-01cf-4fe4-a216-dfe2fc7d7479","type":"GlyphRenderer"},{"id":"899b2371-9738-442a-8392-5fae40f9c302","type":"GlyphRenderer"},{"id":"17a42a12-7c5c-415c-a7e0-8787e9f4bf73","type":"GlyphRenderer"},{"id":"fd4e26e9-0f7b-41c4-8cad-fd6956391988","type":"Gl ...

# %%
df.sort('Holidays', inplace=True)
hist = Histogram(df, values='checkins', color='Holidays',
                 title="Checkin distribution by Year", legend='top_right')

#output_notebook("histogram_single", title="histogram_single.py example")

show(hist)

# %% [markdown]
# ## Box plots:

# %%
dfmv = pd.read_csv('/Users/XinyiLu/Documents/Programming/Project/TrainDataNew.csv',header = 0, na_values = 'NA')

# %%
headers = df.dtypes.index

# %%
from bokeh.charts import BoxPlot, output_file, show
from bokeh.layouts import row
#from bokeh.sampledata.autompg import autompg as df

# origin = the source of the data that makes up the autompg dataset


# color by one dimension and label by two dimensions
# coloring by one of the columns visually groups them together

box = BoxPlot(dfmv, values='checkins', label='Jan', plot_width=200, plot_height=200 , color='Jan')
box1 = BoxPlot(dfmv, values='checkins', label='Nov', plot_width=200, plot_height=200 ,color='Nov')
box2 = BoxPlot(dfmv, values='checkins', label='Sun', plot_width=200, plot_height=200 ,color='Sun' )
box3 = BoxPlot(dfmv, values='checkins', label='Fri', plot_width=200, plot_height=200 ,color='Fri' )
box4 = BoxPlot(dfmv, values='checkins', label='Xmas', plot_width=200, plot_height=200 ,color='Xmas' )
box5 = BoxPlot(dfmv, values='checkins', label='Valentines', plot_width=200, plot_height=200 ,color='Valentines' )



#output_file('box.html')
show(row(box,box1,box2,box3,box4,box5))
#output_file("boxplot_single.html", title="boxplot_single.py example")

#show(box)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f280b419-e139-4887-b686-f061eea2b587"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f280b419-e139-4887-b686-f061eea2b587");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f280b419-e139-4887-b686-f061eea2b587' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"84c4fc80-ced7-4153-b17d-781c759f5861":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f33dd996-1f57-4204-a39c-3a86e002cde8","type":"Rect"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"006d0ec2-cffb-45f5-83c0-b145c5aa04f1","type":"Circle"},{"attributes":{"data_source":{"id":"96590ca8-d63f-494e-b517-fd5dc6e074f8","type":"ColumnDataSource"},"glyph":{"id":"79594d93-97e2-478d-b6b8-ce4409e153c2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4e2f4573-d8e9-4423-b6bd-7766651c8231","type":"GlyphRenderer"},{"attributes":{"axis_label":"Fri","formatter":{"id":"beee6e45-40c0-42cf-ac6f-f23365188c7c","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"7b7db456-4a34-4758-b843-8166a53f98bf","subtype":"Chart","type":"Plot"},"ticker":{"id":"c485e4d6-767f-464b-b99b-992eaf13536f","type":"CategoricalTicker"}},"id":"31ee1b2f-b711-4602-a7e1-19b7c899da47","type":"CategoricalAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"78ec875d-19cc-436b-8214-0652c8ece962","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"9d228ee9-17af-420b-8df6-e3ca36f9430b","type":"ColumnDataSource"},"glyph":{"id":"7408fcc8-4540-4f00-9a4e-dcfd13cb1229","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cc544829-8c3a-4a14-957d-47b60ec64cc0","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"a0af1afc-e2c5-4d7a-b73a-e8f000c9d1f7","type":"Circle"},{"attributes":{},"id":"5d676618-f12d-4050-b771-f045d547327f","type":"ToolEvents"},{"attributes":{"data_source":{"id":"ed249f71-abec-4f2a-8109-302d0f4dbb50","type":"ColumnDataSource"},"glyph":{"id":"d3956989-09a0-47cf-bc31-660bbb305f66","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cca56e88-7300-4f72-85d2-d9be37d786c4","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"dcfcb09b-48af-496f-851d-81f03031c0b5","type":"ColumnDataSource"},"glyph":{"id":"ad585bc4-191f-47ff-81d8-5704efd8528f","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5dea77ba-6ed2-483b-8983-e47879b79f80","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"50231e64-0351-41d8-ae65-f2c3bc16b6a4","type":"ColumnDataSource"},"glyph":{"id":"dd6e0488-4c49-4308-bbe9-7cb258e74a15","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e6c1f79f-8e37-4466-867c-77ece68b4802","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":null},"id":"fa5d89e3-7dd6-417e-b7fc-3b78f0c84111","type":"Title"},{"attributes":{"callback":null,"column_names":["fill_alpha","y","label","width","x","line_alpha","color","height","line_color"],"data":{"Jan":[1],"chart_index":[{"Jan":1}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[202.25],"label":[{"Jan":1}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["1"],"y":[980.875]}},"id":"6701bf71-0ca9-4f0a-bc56-b32dfa1f583d","type":"ColumnDataSource"},{"attributes":{},"id":"812af4a0-cdef-4b49-8dbc-81e1097cdb81","type":"CategoricalTickFormatter"},{"attributes":{"callback":null,"end":3467.8},"id":"c8f7a537-68d1-4711-bbb6-23cf7ca7cd59","type":"Range ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[14]</strong>&gt;</code></p>

# %% [markdown]
# ## Multivariate:

# %%
from __future__ import print_function

from bokeh.document import Document
from bokeh.embed import file_html
from bokeh.layouts import gridplot
from bokeh.models.glyphs import Circle
from bokeh.models import (BasicTicker, ColumnDataSource, Grid, LinearAxis,
                         DataRange1d, PanTool, Plot, WheelZoomTool)
from bokeh.resources import INLINE
from bokeh.sampledata.iris import flowers
from bokeh.util.browser import view

colormap = {1: 'red', 0: 'green'}

dfmv['checkins'] = dfmv['JewishHoliday'].map(lambda x: colormap[x])


source = ColumnDataSource(
    data=dict(
        RewardsCardholder=dfmv['RewardsCardholder'],
        SpecialEventCustomer=dfmv['SpecialEventCustomer'],
        FreeAndIndependentTraveler=dfmv['FreeAndIndependentTraveler'],
        WholeSaleCustomer=dfmv['RewardsCardholder'],
        GroupMemberCustomer=dfmv['GroupMemberCustomer'],
        AvgRoomRateFofIndepedentTraveler=dfmv['AvgRoomRateFofIndepedentTraveler'],
        checkins=dfmv['checkins'],
    )
)

xdr = DataRange1d(bounds=None)
ydr = DataRange1d(bounds=None)

def make_plot(xname, yname, xax=False, yax=False):
    mbl = 40 if yax else 0
    mbb = 40 if xax else 0
    plot = Plot(
        x_range=xdr, y_range=ydr, background_fill_color="#efe8e2",
        border_fill_color='white', plot_width=200 + mbl, plot_height=200 + mbb,
        min_border_left=2+mbl, min_border_right=2, min_border_top=2, min_border_bottom=2+mbb)

    circle = Circle(x=xname, y=yname, fill_color="checkins", fill_alpha=0.2, size=4, line_color="checkins")
    r = plot.add_glyph(source, circle)

    xdr.renderers.append(r)
    ydr.renderers.append(r)

    xticker = BasicTicker()
    if xax:
        xaxis = LinearAxis()
        plot.add_layout(xaxis, 'below')
        xticker = xaxis.ticker
    plot.add_layout(Grid(dimension=0, ticker=xticker))

    yticker = BasicTicker()
    if yax:
        yaxis = LinearAxis()
        plot.add_layout(yaxis, 'left')
        yticker = yaxis.ticker
    plot.add_layout(Grid(dimension=1, ticker=yticker))

    plot.add_tools(PanTool(), WheelZoomTool())

    return plot

xattrs = ["RewardsCardholder","SpecialEventCustomer","FreeAndIndependentTraveler","RewardsCardholder","GroupMemberCustomer","AvgRoomRateFofIndepedentTraveler"]
yattrs = list(reversed(xattrs))
plots = []

for y in yattrs:
    row = []
    for x in xattrs:
        xax = (y == yattrs[-1])
        yax = (x == xattrs[0])
        plot = make_plot(x, y, xax, yax)
        row.append(plot)
    plots.append(row)

grid = gridplot(plots)

doc = Document()
doc.add_root(grid)

if __name__ == "__main__":
    doc.validate()
    filename = "iris_splom.html"
    with open(filename, "w") as f:
        f.write(file_html(doc, INLINE, "Iris Data SPLOM"))
    print("Wrote %s" % filename)
    view(filename)
# Out:
# Wrote iris_splom.html

# %% [markdown]
# # Dotplot:

# %% [markdown]
# Explore the coefficients fo each of the independent variables

# %%
factors = ["X1st.of.Month",
"X15th.of.Month",
"JewishHoliday",
"CNY15Days",
"CNY7Days",
"ChineseNewYear",
"SuperBowl",
"Valentines",
"Halloween",
"NewYear'sDay",
"MartinLutherKingDay",
"Pres.Day",
"Easter",
"Memorial",
"MotherDay",
"FatherDay",
"July.4th",
"LaborDay",
"ColumbusDay",
"VeteransDay",
"ThxGiving",
"Xmas",
"LongWKend",
"Jan",
"Feb",
"Mar",
"Apr",
"May",
"Jun",
"Jul",
"Aug",
"Sep",
"Oct",
"Nov",
"Sun",
"Mon",
"Tue",
"Wed",
"Thu",
"Fri",
"RewardsCardholder",
"SpecialEventCustomer",
"FreeAndIndependentTraveler",
"WholeSaleCustomer",
"GroupMemberCustomer",
"AvgRoomRateFofIndepedentTraveler"]

x =  [70.09011589,
154.3671354,
13.44997604,
7.22065767,
147.1746085,
21.77346785,
-771.2636539,
-434.3927166,
-374.9450608,
-515.7056398,
1040.608809,
1445.769212,
-145.6067709,
347.0164622,
-25.95016057,
-48.66063418,
-270.7105155,
136.8744036,
73.41669628,
169.3185561,
213.2460654,
-250.1389057,
-174.336851,
32.26334937,
81.78795756,
37.47574626,
99.73011693,
62.85859928,
-12.10380021,
11.25824005,
55.81321054,
52.24021755,
110.3417472,
41.48314857,
576.5211521,
300.2571907,
104.8750951,
149.4442819,
257.7485607,
581.0283683,
0.32981387,
0.134047735,
0.409743303,
0.026037363,
0.232772691,
-0.358254948]

dot = figure(title="Categorical Dot Plot", tools="", toolbar_location=None,
            y_range=factors, x_range=[-800,1500])

dot.segment(0, factors, x, factors, line_width=2, line_color="green", )
dot.circle(x, factors, size=15, fill_color="orange", line_color="green", line_width=3, )

factors = ["foo", "bar", "baz"]
x = ["foo", "foo", "foo", "bar", "bar", "bar", "baz", "baz", "baz"]
y = ["foo", "bar", "baz", "foo", "bar", "baz", "foo", "bar", "baz"]
colors = [
    "#0B486B", "#79BD9A", "#CFF09E",
    "#79BD9A", "#0B486B", "#79BD9A",
    "#CFF09E", "#79BD9A", "#0B486B"
]

hm = figure(title="Categorical Heatmap", tools="hover", toolbar_location=None,
            x_range=factors, y_range=factors)
hm.rect(x, y, color=colors, width=1, height=1)

#output_file("categorical.html", title="categorical.py example")

show(row(dot, sizing_mode="scale_width"))  # open a browser
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="9a7ce5a7-41da-4abb-b149-c306ed38970a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9a7ce5a7-41da-4abb-b149-c306ed38970a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9a7ce5a7-41da-4abb-b149-c306ed38970a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d250064a-4fcc-4014-8e94-8e55d1660a15":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"c58c0eb0-08f2-4716-8b16-b10036d3abb1","subtype":"Figure","type":"Plot"},"ticker":{"id":"9ccb04e2-db6f-4808-924a-9945ba777906","type":"CategoricalTicker"}},"id":"176d214d-1f80-4bcc-aed0-df5553152bdc","type":"Grid"},{"attributes":{"callback":null,"factors":["X1st.of.Month","X15th.of.Month","JewishHoliday","CNY15Days","CNY7Days","ChineseNewYear","SuperBowl","Valentines","Halloween","NewYear'sDay","MartinLutherKingDay","Pres.Day","Easter","Memorial","MotherDay","FatherDay","July.4th","LaborDay","ColumbusDay","VeteransDay","ThxGiving","Xmas","LongWKend","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Sun","Mon","Tue","Wed","Thu","Fri","RewardsCardholder","SpecialEventCustomer","FreeAndIndependentTraveler","WholeSaleCustomer","GroupMemberCustomer","AvgRoomRateFofIndepedentTraveler"]},"id":"622513ac-dd98-4556-8be0-21268260fba1","type":"FactorRange"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x0":{"value":0},"x1":{"field":"x1"},"y0":{"field":"y0"},"y1":{"field":"y1"}},"id":"7c2711e3-ec57-47a3-b6e0-5bd4d628ace7","type":"Segment"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"size":{"units":"screen","value":15},"x":{"field":"x"},"y":{"field":"y"}},"id":"a08aa07d-2675-4dc1-a1af-0fd54ffcf103","type":"Circle"},{"attributes":{"fill_color":{"value":"orange"},"line_color":{"value":"green"},"line_width":{"value":3},"size":{"units":"screen","value":15},"x":{"field":"x"},"y":{"field":"y"}},"id":"0285c4fe-9c54-4253-8739-a4009e7b812b","type":"Circle"},{"attributes":{},"id":"43789b13-546a-423a-9c50-f65e1a50cb3f","type":"ToolEvents"},{"attributes":{},"id":"b2d5d665-321a-4c20-aeed-3b2fa3f0f3ce","type":"CategoricalTickFormatter"},{"attributes":{"line_color":{"value":"green"},"line_width":{"value":2},"x0":{"value":0},"x1":{"field":"x1"},"y0":{"field":"y0"},"y1":{"field":"y1"}},"id":"d5df6a7a-b9c4-4664-8a87-d55bccde6a6d","type":"Segment"},{"attributes":{},"id":"6d6744d9-5f80-4af5-b107-37e2f248d632","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"6d6744d9-5f80-4af5-b107-37e2f248d632","type":"BasicTickFormatter"},"plot":{"id":"c58c0eb0-08f2-4716-8b16-b10036d3abb1","subtype":"Figure","type":"Plot"},"ticker":{"id":"f4b1a72b-a94f-470a-a51a-7408b7657680","type":"BasicTicker"}},"id":"0608234c-d37d-4fce-a2de-648234abe63d","type":"LinearAxis"},{"attributes":{"data_source":{"id":"017859e6-b27c-4e5b-a7ea-8b21e7d5805f","type":"ColumnDataSource"},"glyph":{"id":"d5df6a7a-b9c4-4664-8a87-d55bccde6a6d","type":"Segment"},"hover_glyph":null,"nonselection_glyph":{"id":"7c2711e3-ec57-47a3-b6e0-5bd4d628ace7","type":"Segment"},"selection_glyph":null},"id":"fd7bc8eb-1ee1-44dc-8bf0-853852512668","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":1500,"start":-800},"id":"e0e83340-9726-4a97-ba27-d438b95366ba","type":"Range1d"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[70.09011589,154.3671354,13.44997604,7.22065767,147.1746085,21.77346785,-771.2636539,-434.3927166,-374.9450608,-515.7056398,1040.608809,1445.769212,-145.6067709,347.0164622,-25.95016057,-48.66063418,-270.7105155,136.8744036,73.41669628,169.3185561,213.2460654,-250.1389057,-174.336851,32.26334937,81.78795756,37.47574626,99.73011693,62.85859928,-12.10380021,11.25824005,55.81321054,52.24021755,110.3417472,41.48314857,576.5211521,300.2571907,104.8750951,149.4442819,257.7485607,581.0283683,0.32981387,0.134047735,0.409743303,0.026037363,0.232772691,-0.358254948],"y":["X1st.of.Month","X15th.of.Month","JewishHoliday","CNY15Days","CNY7Days","ChineseNewYear","SuperBowl","Valentines","Halloween","NewYear'sDay","MartinLutherKingDay","Pres.Day","Easter","Memorial","MotherDay","FatherDay","July.4th","LaborDay","ColumbusDay","VeteransDay","ThxGiving","Xmas","L ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[14]</strong>&gt;</code></p>

# %% [markdown]
# # Forecasts：

# %%
import csv
import pandas as pd
import scipy

# %%
df = pd.read_csv('ForecastDataNew.csv')
df
# Out:
#               Date  ActualCheckins  Predicted-MA  Predicted-Reg
# 0      1/1/10 0:00             650             0     812.515115
# 1      1/2/10 0:00            1028             0     641.811214
# 2      1/3/10 0:00             944             0    1131.799437
# 3      1/4/10 0:00            1086             0     981.261214
# 4      1/5/10 0:00            1071             0     850.613456
# 5      1/6/10 0:00            1498             0    1025.782802
# 6      1/7/10 0:00             977             0    1079.030033
# 7      1/8/10 0:00             899             0    1448.109028
# 8      1/9/10 0:00             801             0     924.140511
# 9     1/10/10 0:00            1020             0    1384.140412
# 10    1/11/10 0:00            1018             0    1030.908652
# 11    1/12/10 0:00             958             0     921.132923
# 12    1/13/10 0:00             800             0     921.122098
# 13    1/14/10 0:00            1151             0    1015.347514
# 14    1/15/10 0:00            1825             0    1638.160146
# 15    1/16/10 0:00             814             0     728.107363
# 16    1/17/10 0:00            1029             0    1272.681115
# 17    1/18/10 0:00            1457             0    1862.393691
# 18    1/19/10 0:00            1080             0     838.211926
# 19    1/20/10 0:00             634             0     907.990528
# 20    1/21/10 0:00             853             0     951.953426
# 21    1/22/10 0:00            1338          1125    1378.414937
# 22    1/23/10 0:00            1181           881     849.226773
# 23    1/24/10 0:00            1495           998    1510.641591
# 24    1/25/10 0:00             583          1187    1076.550932
# 25    1/26/10 0:00             740          1036     922.170017
# 26    1/27/10 0:00            1000           977     848.493971
# 27    1/28/10 0:00            1341           994    1077.896352
# 28    1/29/10 0:00            1381          1354    1466.499111
# 29    1/30/10 0:00             714           932     882.386747
# ...            ...             ...           ...            ...
# 1307  7/31/13 0:00             300           631     824.566080
# 1308   8/1/13 0:00             393           406    1114.180180
# 1309   8/2/13 0:00            1917          1791            NaN
# 1310   8/3/13 0:00            1067          1121            NaN
# 1311   8/4/13 0:00            1598          1505            NaN
# 1312   8/5/13 0:00            1343          1088            NaN
# 1313   8/6/13 0:00             949          1264            NaN
# 1314   8/7/13 0:00            1040           669            NaN
# 1315   8/8/13 0:00             519           453            NaN
# 1316   8/9/13 0:00            1531          1771            NaN
# 1317  8/10/13 0:00            1427          1016            NaN
# 1318  8/11/13 0:00            1430          1456            NaN
# 1319  8/12/13 0:00            1053          1015            NaN
# 1320  8/13/13 0:00            1124          1291            NaN
# 1321  8/14/13 0:00            1101           629            NaN
# 1322  8/15/13 0:00             610           451            NaN
# 1323  8/16/13 0:00            1845          1716            NaN
# 1324  8/17/13 0:00            1090           950            NaN
# 1325  8/18/13 0:00            2035          1450            NaN
# 1326  8/19/13 0:00             809           937            NaN
# 1327  8/20/13 0:00             450          1381            NaN
# 1328  8/21/13 0:00             478           533            NaN
# 1329  8/22/13 0:00             511           432            NaN
# 1330  8/23/13 0:00            1955          1759            NaN
# 1331  8/24/13 0:00            1001          1029            NaN
# 1332  8/25/13 0:00            1775          1470            NaN
# 1333  8/26/13 0:00            1068          1013            NaN
# 1334  8/27/13 0:00             769          1312            NaN
# 1335  8/28/13 0:00             887           610            NaN
# 1336  8/29/13 0:00             517           445            NaN
#
# [1337 rows x 4 columns]

# %%
# !pwd
# Out:
# /Users/XinyiLu/Documents/Programming/Project

# %%
from IPython.display import Image
PATH = "/Users/XinyiLu/Documents/Programming/Project/"

# %% [markdown]
# # Prediction from Moving Average Method and the Actual values：

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/ActualAndMA.png)

# %% [markdown]
# # Prediction from Regression Method and the Actual values：

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/ActualAndReg.png)

# %%
df.Date = pd.to_datetime(df['Date'], format='%m/%d/%y %H:%M')
df.set_index(['Date'],inplace=True)
df.plot()

# %% [markdown]
# From the graph we can see that the regression model fits better than the moving average model.

# %% [markdown]
# Smaller MAPE for Regression and less Maximum error compared to Moving Average .

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/MAPE.png)
