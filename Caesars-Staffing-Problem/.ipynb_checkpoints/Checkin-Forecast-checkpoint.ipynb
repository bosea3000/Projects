# %% [markdown]
# # Hotel Caesar

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/Images/Caesar.png)

# %% [markdown]
# # Financial Data

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/Images/Financials.png)

# %% [markdown]
# # Workflow

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/Images/FlowChart.png)

# %% [markdown]
# # Pre-analysis Exploration

# %% [markdown]
# ## Histograms:

# %%
from bokeh.layouts import row
from bokeh.plotting import figure, show, output_file
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9a1ac3c5-dee3-4271-9bb0-a11c542f105a">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.charts import Histogram, output_file, show
import pandas as pd

df = pd.read_csv('Transform-Data/TrainData.csv')

# %%
from bokeh.charts import Bar, show
df.sort('Year')
p = Bar(df, label='Year', values='checkins', agg='sum',
        title="Average checkins by Year", legend = False, color = 'blue')
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
p.ygrid.grid_line_alpha = 0.5
p.outline_line_width = 7
p.outline_line_alpha = 0.3
p.outline_line_color = "navy"

#output_file("bar.html")

show(p)
# Out:
# /Users/Bose/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#     <div class="bk-root">
#         <div class="plotdiv" id="3f3d4def-66e2-4e58-9420-b2c0ca20e234"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#3f3d4def-66e2-4e58-9420-b2c0ca20e234").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3f3d4def-66e2-4e58-9420-b2c0ca20e234");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3f3d4def-66e2-4e58-9420-b2c0ca20e234' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c560430b-db79-4a2f-b54d-803fe9571072":{"roots":{"references":[{"attributes":{"dimension":1,"grid_line_alpha":{"value":0.5},"plot":{"id":"25adf9af-ffd4-4799-96a7-4c00d0d6b12f","subtype":"Chart","type":"Plot"},"ticker":{"id":"a250a6b9-7b15-4c35-bc42-8f3cc67972ac","type":"BasicTicker"}},"id":"bcf95eba-80a6-45e7-9603-e1f14b2d2868","type":"Grid"},{"attributes":{"data_source":{"id":"e6a4399b-ff62-404b-b542-b4b2dcd9f8df","type":"ColumnDataSource"},"glyph":{"id":"dbca5e22-297d-447b-bbc0-6f5e2a254161","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"69bb875b-c67f-4dbf-a744-0a111bbfae75","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dbca5e22-297d-447b-bbc0-6f5e2a254161","type":"Rect"},{"attributes":{},"id":"75c3d8cf-8edc-4989-be1c-7e8f4108848e","type":"CategoricalTickFormatter"},{"attributes":{"plot":{"id":"25adf9af-ffd4-4799-96a7-4c00d0d6b12f","subtype":"Chart","type":"Plot"}},"id":"041a849a-3543-4ced-87ba-4c438c1127c6","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","height","width","y","color","x","label","fill_alpha"],"data":{"Year":[2012],"chart_index":[{"Year":2012}],"color":["blue"],"fill_alpha":[0.8],"height":[477260.0],"label":[{"Year":2012}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["2012"],"y":[238630.0]}},"id":"b3db344e-5d48-480a-a6b4-c2b5864d1ead","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6271d33e-4337-4caf-be2d-9ec8ea0a89f0","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c2657091-f3cb-4802-a28f-53ff58f62923","type":"Rect"},{"attributes":{"axis_label":"Year","formatter":{"id":"75c3d8cf-8edc-4989-be1c-7e8f4108848e","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"25adf9af-ffd4-4799-96a7-4c00d0d6b12f","subtype":"Chart","type":"Plot"},"ticker":{"id":"0493a9d4-beb0-46c7-88ff-9431230b68e6","type":"CategoricalTicker"}},"id":"8ef3ee23-d280-4979-a47e-22c6f91513c2","type":"CategoricalAxis"},{"attributes":{},"id":"5209e63c-e81a-44a0-8941-67dff4823fc2","type":"ToolEvents"},{"attributes":{},"id":"2eb12ab3-719b-4be6-bdd3-4b7d0969622e","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"25adf9af-ffd4-4799-96a7-4c00d0d6b12f","subtype":"Chart","type":"Plot"}},"id":"54000c50-0539-47a5-8b70-33df04522b50","type":"SaveTool"},{"attributes":{"background_fill_alpha":{"value":0.5},"background_fill_color":{"value":"beige"},"below":[{"id":"8ef3ee23-d280-4979-a47e-22c6f91513c2","type":"CategoricalAxis"}],"left":[{"id":"3a4edecd-4c3c-4b62-93a4-250e78b28417","type":"LinearAxis"}],"outline_line_alpha":{"value":0.3},"outline_line_color":{"value":"navy"},"outline_line_width":{"value":7},"renderers":[{"id":"6271d33e-4337-4caf-be2d-9ec8ea0a89f0","type":"BoxAnnotation"},{"id":"2b27a49d-aac7-4687-a415-0a91f8ba7836","type":"GlyphRenderer"},{"id":"69bb875b-c67f-4dbf-a744-0a111bbfae75","type":"GlyphRenderer"},{"id":"e49ee963-7a27-4d9f-b34e-c3f50433b3e1","type":"GlyphRenderer"},{"id":"c944462e-5daa-4ccb-aff7-f75f4a84e235","type":"GlyphRenderer"},{"id":"8ef3ee23-d280-4979-a47e-22c6f91513c2","type":"CategoricalAxis"},{"id":"3a4edecd-4c3c-4b62-93a4-250e78b28417","type":"LinearAxis"},{"id":"bcf95eba-80a6-45e7-9603-e1f14b2d2868","type":"Grid"}]," ...

# %%
from bokeh.charts import Bar, show
df.sort('Days')
p = Bar(df, label='Months', values='checkins', agg='mean',
        title="Average checkins by Months", legend = False)
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
p.ygrid.grid_line_alpha = 0.5
p.ygrid.grid_line_dash = [6, 4]
p.outline_line_width = 7
p.outline_line_alpha = 0.3
p.outline_line_color = "navy"

#output_file("bar.html")

show(p)
# Out:
# /Users/Bose/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#     <div class="bk-root">
#         <div class="plotdiv" id="4fb74f8a-6a06-40ce-a4cd-10bec384ce7e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#4fb74f8a-6a06-40ce-a4cd-10bec384ce7e").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4fb74f8a-6a06-40ce-a4cd-10bec384ce7e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4fb74f8a-6a06-40ce-a4cd-10bec384ce7e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1a4b037e-86f1-42f4-9609-f262dbdc373f":{"roots":{"references":[{"attributes":{},"id":"75698faa-eceb-4945-8dd2-2c5df3844f75","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"e1d5ef90-2029-4c00-a14a-5c074af79953","subtype":"Chart","type":"Plot"}},"id":"f9691523-31d6-4370-97d5-c88be6ad24d7","type":"ResetTool"},{"attributes":{"overlay":{"id":"2e95a009-ea24-4ebb-bc41-251dbd2f7f7f","type":"BoxAnnotation"},"plot":{"id":"e1d5ef90-2029-4c00-a14a-5c074af79953","subtype":"Chart","type":"Plot"}},"id":"e5ae22d1-d524-47b9-bac9-c2580081e0a3","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"ac781415-7c0f-4ba2-9461-27e5baaa0624","type":"ColumnDataSource"},"glyph":{"id":"d36cca20-34cc-4f79-8982-4a16a308d571","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e6f38791-703f-44ca-a8a9-598a26db3af1","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"02fa1ab4-f5c4-4aa7-ae89-19c272f565ca","type":"ColumnDataSource"},"glyph":{"id":"5bfb0ad3-ef6b-4e82-9c22-8d4c58248f45","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"67819e00-c512-4d6d-8636-bcbcc7a7aca8","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","height","width","y","color","x","label","fill_alpha"],"data":{"Months":["JUN"],"chart_index":[{"Months":"JUN"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1123.95],"label":[{"Months":"JUN"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["JUN"],"y":[561.975]}},"id":"ac781415-7c0f-4ba2-9461-27e5baaa0624","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5bfb0ad3-ef6b-4e82-9c22-8d4c58248f45","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cf5a7f50-32e2-4b51-a751-2d435fc6d6a8","type":"Rect"},{"attributes":{},"id":"bf860ae6-bd3b-4c23-8100-a7e99e44e2f8","type":"CategoricalTickFormatter"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","height","width","y","color","x","label","fill_alpha"],"data":{"Months":["APR"],"chart_index":[{"Months":"APR"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1181.7916666666667],"label":[{"Months":"APR"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["APR"],"y":[590.8958333333334]}},"id":"dca9d27f-17c1-417a-890f-e83541074ff5","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":1276.6234513274335},"id":"5292cef1-0c82-42d3-84e0-79bd99e38ab5","type":"Range1d"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d36cca20-34cc-4f79-8982-4a16a308d571","type":"Rect"},{"attributes":{"data_source":{"id":"b74cf397-567c-4d88-b75a-1182eedd8326","type":"ColumnDataSource"},"glyph":{"id":"8142f171-55f1-413f-8c87-d777fd2fb070","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"64e73ab7-a09e-4e95-8b1c-5acd9a9e6d85","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"44973fc6-3ee5-4205-b0f4-99deea31033c","type":"Rect"},{"attributes":{"plot":{"id":"e1d5ef90-2029-4c00-a14a-5c074af79953","subtype":"Chart","type":"Plot"}},"id":"6d28d408-813a-4312-920f-329e33af6739","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_n ...

# %%
df.sort('Days')
from bokeh.plotting import figure

p = Bar(df, label='Days', values='checkins', agg='mean',
        title="Average checkins by Days", legend= False, color = 'navy')
p.outline_line_width = 7
p.outline_line_alpha = 0.3
p.outline_line_color = "navy"
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
p.ygrid.grid_line_alpha = 0.5

#output_file("bar.html")

show(p)
# Out:
# /Users/Bose/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#     <div class="bk-root">
#         <div class="plotdiv" id="90927c0e-941a-4987-939b-665803d33baa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#90927c0e-941a-4987-939b-665803d33baa").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("90927c0e-941a-4987-939b-665803d33baa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '90927c0e-941a-4987-939b-665803d33baa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9ee4e9db-6b11-47c9-85fb-1cb580ecb90c":{"roots":{"references":[{"attributes":{"background_fill_alpha":{"value":0.5},"background_fill_color":{"value":"beige"},"below":[{"id":"fb2bc712-61d0-4758-a493-612ef8d9e805","type":"CategoricalAxis"}],"left":[{"id":"6a36d5dc-36c9-4c79-98d7-a63c4e919f81","type":"LinearAxis"}],"outline_line_alpha":{"value":0.3},"outline_line_color":{"value":"navy"},"outline_line_width":{"value":7},"renderers":[{"id":"59cbdde2-846f-4c22-840f-eb3fcdf3a16b","type":"BoxAnnotation"},{"id":"350109fd-fb08-4549-b0a7-fe51b8a690d6","type":"GlyphRenderer"},{"id":"0211728e-4fae-45ee-82ef-b04e0948e0af","type":"GlyphRenderer"},{"id":"aac48c8e-5842-41d4-b71c-bad9292a43b3","type":"GlyphRenderer"},{"id":"9da9c36d-a1c0-4a87-904c-52f90e4e09f7","type":"GlyphRenderer"},{"id":"2433ff45-0cc8-448c-ba88-8d5d21bace26","type":"GlyphRenderer"},{"id":"d2b20867-73e3-4d97-b240-7c295d7ae61e","type":"GlyphRenderer"},{"id":"d8c8bb0b-412c-47f0-adac-7a22ccee4451","type":"GlyphRenderer"},{"id":"fb2bc712-61d0-4758-a493-612ef8d9e805","type":"CategoricalAxis"},{"id":"6a36d5dc-36c9-4c79-98d7-a63c4e919f81","type":"LinearAxis"},{"id":"ac75e347-dc03-4b61-9a01-616c021c6b97","type":"Grid"}],"title":{"id":"683b5b8c-a77a-4c23-b005-f96f40fe326c","type":"Title"},"tool_events":{"id":"032741e1-f302-47ca-b868-bca7c2e5265a","type":"ToolEvents"},"toolbar":{"id":"4d22bfc7-a996-44ca-b985-d2f0dbf3e116","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"ffe23875-c064-48a0-95a6-69b166ab2105","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"6ed91036-936a-42e3-b541-b8286ba50bdf","type":"Range1d"}},"id":"28561b75-f762-44bd-ace1-42ad9cf5fae9","subtype":"Chart","type":"Plot"},{"attributes":{"data_source":{"id":"5f1bce91-4394-4451-ba30-7c3bb7658615","type":"ColumnDataSource"},"glyph":{"id":"9f7d196e-c629-49d2-99e0-3d6f37949324","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0211728e-4fae-45ee-82ef-b04e0948e0af","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","height","width","y","color","x","label","fill_alpha"],"data":{"Days":["FRI"],"chart_index":[{"Days":"FRI"}],"color":["navy"],"fill_alpha":[0.8],"height":[1514.1069518716577],"label":[{"Days":"FRI"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["FRI"],"y":[757.0534759358288]}},"id":"fa23ae7d-a766-407b-b4df-bbeb3b2182f7","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","height","width","y","color","x","label","fill_alpha"],"data":{"Days":["TUE"],"chart_index":[{"Days":"TUE"}],"color":["navy"],"fill_alpha":[0.8],"height":[949.2566844919786],"label":[{"Days":"TUE"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["TUE"],"y":[474.6283422459893]}},"id":"175b99a7-4b69-4fac-99d3-87e67b39c30a","type":"ColumnDataSource"},{"attributes":{"axis_label":"Days","formatter":{"id":"98814c04-bcff-4e03-af72-fb2e38acb93f","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"28561b75-f762-44bd-ace1-42ad9cf5fae9","subtype":"Chart","type":"Plot"},"ticker":{"id":"2fc81212-80df-4120-ac26-ec52cffa3feb","type":"CategoricalTicker"}},"id":"fb2bc712-61d0-4758-a493-612ef8d9e805","type":"CategoricalAxis"},{"attributes":{"plot":{"id":"28561b75-f762-44bd-ace1-42ad9cf5fae9","subtype":"Chart","type":"Plot"}},"id":"0c467cd1-1ea0-4be1-bedd-47d4cd317554","type":"HelpTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9f7d196e-c629-49d2-99e0-3d6f37949324","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}}, ...

# %%
df.sort('Holidays')
p = Bar(df, label='Holidays', values='checkins', agg='sum',
        title="Total checkins by Holidays", legend= False)
p.outline_line_width = 7
p.outline_line_alpha = 0.3
p.outline_line_color = "navy"
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
p.ygrid.grid_line_alpha = 0.5
#output_file("bar.html")

show(p)
# Out:
# /Users/Bose/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#     <div class="bk-root">
#         <div class="plotdiv" id="794b938d-5d8d-4384-b16c-cc0a4dcdb25e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#794b938d-5d8d-4384-b16c-cc0a4dcdb25e").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("794b938d-5d8d-4384-b16c-cc0a4dcdb25e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '794b938d-5d8d-4384-b16c-cc0a4dcdb25e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c0869475-87d3-484b-9156-ad0e382e194a":{"roots":{"references":[{"attributes":{},"id":"d12b53b7-ab07-403b-b6ce-31fc30516639","type":"BasicTicker"},{"attributes":{"plot":{"id":"ff7e4b1e-a28a-41c9-bc3e-015bcd149911","subtype":"Chart","type":"Plot"}},"id":"f7937615-8e84-4cb2-85ae-f34e295890e6","type":"SaveTool"},{"attributes":{"data_source":{"id":"c1b6f571-79b4-4bf4-bf91-c9d40105bff0","type":"ColumnDataSource"},"glyph":{"id":"5ec6d1e7-4931-4103-bfd8-274d5144259d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1e917696-c360-4e8c-8850-d7c11d92a8dd","type":"GlyphRenderer"},{"attributes":{"background_fill_alpha":{"value":0.5},"background_fill_color":{"value":"beige"},"below":[{"id":"bae46266-b59c-4325-a604-3adf1c1856e3","type":"CategoricalAxis"}],"left":[{"id":"c6bf8683-3d92-4c51-9f89-fd223241b931","type":"LinearAxis"}],"outline_line_alpha":{"value":0.3},"outline_line_color":{"value":"navy"},"outline_line_width":{"value":7},"renderers":[{"id":"329884c8-b637-4552-8e5d-c58ca951cd82","type":"BoxAnnotation"},{"id":"c9c9396c-91e4-4655-bdc5-33033e90b8d0","type":"GlyphRenderer"},{"id":"b3b66d69-53d7-454f-b2a7-03cecd6e1926","type":"GlyphRenderer"},{"id":"40c27a38-4e66-4f06-aa55-cfa61a50201a","type":"GlyphRenderer"},{"id":"54db3ae6-8f17-4d01-b5fc-3002affe6c82","type":"GlyphRenderer"},{"id":"a2448a1d-5848-4f04-82be-ee7cec5768c3","type":"GlyphRenderer"},{"id":"cf88471b-e440-4f4f-a62d-665f93faff80","type":"GlyphRenderer"},{"id":"994e4ff9-70a1-4b89-83e8-5874b7a5eb1b","type":"GlyphRenderer"},{"id":"5bed0013-ab00-40e3-b55b-201ac0db713b","type":"GlyphRenderer"},{"id":"95070eb4-9490-49ed-a9c0-8267af6dfff1","type":"GlyphRenderer"},{"id":"08b851b2-5de3-4c56-9f4c-0f3a47de8ed0","type":"GlyphRenderer"},{"id":"a9dea6d6-65eb-44ee-978d-809ca9a4a02f","type":"GlyphRenderer"},{"id":"49a7b14e-9f7e-44c8-bde9-8da72dbec06c","type":"GlyphRenderer"},{"id":"6962d986-f504-450f-9f9a-265d5e5c3618","type":"GlyphRenderer"},{"id":"7972dc9c-913b-4207-ae8b-40e0faf3c693","type":"GlyphRenderer"},{"id":"b50b4fd5-583c-43bc-9d47-877678db1ecf","type":"GlyphRenderer"},{"id":"0944b92f-95e2-4f2f-87c3-fbd6f5b5e24f","type":"GlyphRenderer"},{"id":"3f543d75-460f-4a66-9687-da5ce469bc41","type":"GlyphRenderer"},{"id":"ee78b13a-6d3f-4949-aa5a-ac2eadc05e7c","type":"GlyphRenderer"},{"id":"1e917696-c360-4e8c-8850-d7c11d92a8dd","type":"GlyphRenderer"},{"id":"a6fe3cc4-5736-4b57-9b1f-15d5bfab5ee2","type":"GlyphRenderer"},{"id":"655fdacf-f62f-48e8-8a22-8fcae7cfca5e","type":"GlyphRenderer"},{"id":"bae46266-b59c-4325-a604-3adf1c1856e3","type":"CategoricalAxis"},{"id":"c6bf8683-3d92-4c51-9f89-fd223241b931","type":"LinearAxis"},{"id":"14e1f922-3cfd-4e23-92d9-a4df63429bf7","type":"Grid"}],"title":{"id":"00fd5e01-9c2e-4126-be5a-1993a3e0563a","type":"Title"},"tool_events":{"id":"55aac3ff-36e1-45a9-9ab2-25f0313ab6c9","type":"ToolEvents"},"toolbar":{"id":"7af34bd4-90cc-4ac5-9a1d-cfde08021635","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"4c2b1db5-c849-4e03-a968-c76a2e1819b3","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"29008923-fd1f-44a2-a85d-a0a055acc911","type":"Range1d"}},"id":"ff7e4b1e-a28a-41c9-bc3e-015bcd149911","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","height","width","y","color","x","label","fill_alpha"],"data":{"Holidays":["Easter"],"chart_index":[{"Holidays":"Easter"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1238.0],"label":[{"Holidays":"Easter"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Easter"],"y":[619.0]}},"id":"b25cbcb6-83b5-42c6-8081-3be919881d9f","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"67734e1b-7dec-4a7c-9eaa-bc96a66a8f6e","type":"Rect"},{"attributes":{"fill_alpha":{"fiel ...

# %% [markdown]
# ## Box plots:

# %%
dfmv = pd.read_csv('Transform-Data/TrainData2.csv',header = 0, na_values = 'NA')

# %%
headers = df.dtypes.index

# %%
from bokeh.charts import BoxPlot, output_file, show
from bokeh.layouts import row
#from bokeh.sampledata.autompg import autompg as df

# origin = the source of the data that makes up the autompg dataset


# color by one dimension and label by two dimensions
# coloring by one of the columns visually groups them together

box = BoxPlot(dfmv, values='checkins', label='Jan', plot_width=200, plot_height=200 , color='Jan')
box1 = BoxPlot(dfmv, values='checkins', label='Nov', plot_width=200, plot_height=200 ,color='Nov')
box2 = BoxPlot(dfmv, values='checkins', label='Sun', plot_width=200, plot_height=200 ,color='Sun' )
box3 = BoxPlot(dfmv, values='checkins', label='Fri', plot_width=200, plot_height=200 ,color='Fri' )
box4 = BoxPlot(dfmv, values='checkins', label='Xmas', plot_width=200, plot_height=200 ,color='Xmas' )
box5 = BoxPlot(dfmv, values='checkins', label='Valentines', plot_width=200, plot_height=200 ,color='Valentines' )



#output_file('box.html')
show(row(box,box1,box2,box3,box4,box5))
#output_file("boxplot_single.html", title="boxplot_single.py example")

#show(box)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="b2c0a512-69c5-4efe-a432-570221044617"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#b2c0a512-69c5-4efe-a432-570221044617").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b2c0a512-69c5-4efe-a432-570221044617");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b2c0a512-69c5-4efe-a432-570221044617' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"224ff595-a5e7-496a-ac19-d05a4a92cb36":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Nov":[1],"chart_index":[{"Nov":1}],"x_values":["1:0.5"],"y_values":[2239]}},"id":"28535993-2e92-4058-8e35-e2321826e6ba","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d6cfa4b1-1aa9-4861-b417-327834dae756","type":"Rect"},{"attributes":{"data_source":{"id":"33651fd1-df60-40e7-a588-42ee65c502e6","type":"ColumnDataSource"},"glyph":{"id":"2e7209fe-cbce-4467-b9e0-1ad543defd1e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ea0b1729-9851-418f-8910-f514638269ce","type":"GlyphRenderer"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"684d3c41-07e4-4d3d-8adc-1bca1a277612","type":"Segment"},{"attributes":{"callback":null,"end":3467.8},"id":"23f15485-1dc8-4f00-bef7-8fe747d63e08","type":"Range1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0628339b-2d1b-4285-a8bb-b1c4a3a3edd1","type":"PanTool"},{"id":"f7febf1d-3790-4602-afd1-f130f66ae174","type":"WheelZoomTool"},{"id":"aaa0415a-62d7-4487-8b77-dfc9278b321f","type":"BoxZoomTool"},{"id":"20022591-5a25-4289-a304-326baa2a0218","type":"SaveTool"},{"id":"b1aaf00b-f811-413c-9e87-eaa8190063bd","type":"ResetTool"},{"id":"2a1e0af0-2271-4a50-9584-631e873ffedf","type":"HelpTool"}]},"id":"45c81e73-616c-4a7e-89c2-2b2d3da46455","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","height","width","y","color","x","label","fill_alpha"],"data":{"Sun":[1],"chart_index":[{"Sun":1}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[189.5],"label":[{"Sun":1}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["1"],"y":[1301.25]}},"id":"6ebe7f8c-72d9-4a92-b06b-dba5f42a7f4c","type":"ColumnDataSource"},{"attributes":{"items":[{"id":"30fde92b-a87d-4ee4-898c-311761bba892","type":"LegendItem"},{"id":"2cf77fdd-9300-43de-b2bc-f887ec8bdc12","type":"LegendItem"}],"location":"top_left","plot":{"id":"8ff16925-9b16-429f-947e-65c10d1ee333","subtype":"Chart","type":"Plot"}},"id":"df895914-c78e-4cb4-acf8-24cc8b8a5466","type":"Legend"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"10a25137-b8b8-486c-b9ed-bf687e87daae","type":"Circle"},{"attributes":{},"id":"5d8b9790-4855-4941-bd12-968684086ed0","type":"CategoricalTicker"},{"attributes":{"data_source":{"id":"ff3fa12f-b361-4e88-9f3a-d4354c4c5632","type":"ColumnDataSource"},"glyph":{"id":"61b3180a-41c7-41c6-88a0-6ff0a454520c","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9b5b2cdc-454a-4f88-bf45-6c7bf158c629","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"8ff16925-9b16-429f-947e-65c10d1ee333","subtype":"Chart","type":"Plot"}},"id":"97c15197-ac89-4e81-a2ac-0a66a7db6cbb","type":"SaveTool"},{"attributes":{"overlay":{"id":"002baf07-8c77-43f1-87dc-32fb02ab256d","type":"BoxAnnotation"},"plot":{"id":"18192dfc-e9d2-4045-9a0e-d92cdf778d4c","subtype":"Chart","type":"Plot"}},"id":"7261a04d-d7bb-478a-a570-6bf2f3e72e44","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"7f8b4dd3-faef-4528-b2ec-6498df576756","subtype":"Chart","type":"Plot"}},"id":"b932745b-4d0f-4fe3-93ca-acd833956329","type":"PanTool"},{"attributes":{"data_source":{"id":"e8720fa6-34a8-44ab-bc85-4c5644db92ce","type":"ColumnDataSource"},"glyph":{"id":"d6cfa4b1-1aa9-4861-b417-327834dae756","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"587a768b-8e79-411b-bf5e-6e5d977f5aa0","type":"Glyp ...

# %% [markdown]
# ## Multivariate:

# %%
from __future__ import print_function

from bokeh.document import Document
from bokeh.embed import file_html
from bokeh.layouts import gridplot
from bokeh.models.glyphs import Circle
from bokeh.models import (BasicTicker, ColumnDataSource, Grid, LinearAxis,
                         DataRange1d, PanTool, Plot, WheelZoomTool)
from bokeh.resources import INLINE
from bokeh.sampledata.iris import flowers
from bokeh.util.browser import view

colormap = {1: 'red', 0: 'green'}

dfmv['checkins'] = dfmv['JewishHoliday'].map(lambda x: colormap[x])


source = ColumnDataSource(
    data=dict(
        RewardsCardholder=dfmv['RewardsCardholder'],
        SpecialEventCustomer=dfmv['SpecialEventCustomer'],
        FreeAndIndependentTraveler=dfmv['FreeAndIndependentTraveler'],
        WholeSaleCustomer=dfmv['RewardsCardholder'],
        GroupMemberCustomer=dfmv['GroupMemberCustomer'],
        AvgRoomRateFofIndepedentTraveler=dfmv['AvgRoomRateFofIndepedentTraveler'],
        checkins=dfmv['checkins'],
    )
)

xdr = DataRange1d(bounds=None)
ydr = DataRange1d(bounds=None)

def make_plot(xname, yname, xax=False, yax=False):
    mbl = 40 if yax else 0
    mbb = 40 if xax else 0
    plot = Plot(
        x_range=xdr, y_range=ydr, background_fill_color="#efe8e2",
        border_fill_color='white', plot_width=200 + mbl, plot_height=200 + mbb,
        min_border_left=2+mbl, min_border_right=2, min_border_top=2, min_border_bottom=2+mbb)

    circle = Circle(x=xname, y=yname, fill_color="checkins", fill_alpha=0.2, size=4, line_color="checkins")
    r = plot.add_glyph(source, circle)

    xdr.renderers.append(r)
    ydr.renderers.append(r)

    xticker = BasicTicker()
    if xax:
        xaxis = LinearAxis()
        plot.add_layout(xaxis, 'below')
        xticker = xaxis.ticker
    plot.add_layout(Grid(dimension=0, ticker=xticker))

    yticker = BasicTicker()
    if yax:
        yaxis = LinearAxis()
        plot.add_layout(yaxis, 'left')
        yticker = yaxis.ticker
    plot.add_layout(Grid(dimension=1, ticker=yticker))

    plot.add_tools(PanTool(), WheelZoomTool())

    return plot

xattrs = ["RewardsCardholder","SpecialEventCustomer","FreeAndIndependentTraveler","RewardsCardholder","GroupMemberCustomer","AvgRoomRateFofIndepedentTraveler"]
yattrs = list(reversed(xattrs))
plots = []

for y in yattrs:
    row = []
    for x in xattrs:
        xax = (y == yattrs[-1])
        yax = (x == xattrs[0])
        plot = make_plot(x, y, xax, yax)
        row.append(plot)
    plots.append(row)

grid = gridplot(plots)

doc = Document()
doc.add_root(grid)

if __name__ == "__main__":
    doc.validate()
    filename = "iris_splom.html"
    with open(filename, "w") as f:
        f.write(file_html(doc, INLINE, "Iris Data SPLOM"))
    print("Wrote %s" % filename)
    view(filename)
# Out:
# Wrote iris_splom.html

# %% [markdown]
# # Dotplot:

# %% [markdown]
# Explore the coefficients fo each of the independent variables

# %%
factors = ["X1st.of.Month",
"X15th.of.Month",
"JewishHoliday",
"CNY15Days",
"CNY7Days",
"ChineseNewYear",
"SuperBowl",
"Valentines",
"Halloween",
"NewYear'sDay",
"MartinLutherKingDay",
"Pres.Day",
"Easter",
"Memorial",
"MotherDay",
"FatherDay",
"July.4th",
"LaborDay",
"ColumbusDay",
"VeteransDay",
"ThxGiving",
"Xmas",
"LongWKend",
"Jan",
"Feb",
"Mar",
"Apr",
"May",
"Jun",
"Jul",
"Aug",
"Sep",
"Oct",
"Nov",
"Sun",
"Mon",
"Tue",
"Wed",
"Thu",
"Fri",
"RewardsCardholder",
"SpecialEventCustomer",
"FreeAndIndependentTraveler",
"WholeSaleCustomer",
"GroupMemberCustomer",
"AvgRoomRateFofIndepedentTraveler"]

x =  [70.09011589,
154.3671354,
13.44997604,
7.22065767,
147.1746085,
21.77346785,
-771.2636539,
-434.3927166,
-374.9450608,
-515.7056398,
1040.608809,
1445.769212,
-145.6067709,
347.0164622,
-25.95016057,
-48.66063418,
-270.7105155,
136.8744036,
73.41669628,
169.3185561,
213.2460654,
-250.1389057,
-174.336851,
32.26334937,
81.78795756,
37.47574626,
99.73011693,
62.85859928,
-12.10380021,
11.25824005,
55.81321054,
52.24021755,
110.3417472,
41.48314857,
576.5211521,
300.2571907,
104.8750951,
149.4442819,
257.7485607,
581.0283683,
0.32981387,
0.134047735,
0.409743303,
0.026037363,
0.232772691,
-0.358254948]

dot = figure(title="Categorical Dot Plot", tools="", toolbar_location=None,
            y_range=factors, x_range=[-800,1500])

dot.segment(0, factors, x, factors, line_width=2, line_color="green", )
dot.circle(x, factors, size=15, fill_color="orange", line_color="green", line_width=3, )

factors = ["foo", "bar", "baz"]
x = ["foo", "foo", "foo", "bar", "bar", "bar", "baz", "baz", "baz"]
y = ["foo", "bar", "baz", "foo", "bar", "baz", "foo", "bar", "baz"]
colors = [
    "#0B486B", "#79BD9A", "#CFF09E",
    "#79BD9A", "#0B486B", "#79BD9A",
    "#CFF09E", "#79BD9A", "#0B486B"
]

hm = figure(title="Categorical Heatmap", tools="hover", toolbar_location=None,
            x_range=factors, y_range=factors)
hm.rect(x, y, color=colors, width=1, height=1)

#output_file("categorical.html", title="categorical.py example")

show(row(dot, sizing_mode="scale_width"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-e502fb8561a4> in <module>()
#     114 #output_file("categorical.html", title="categorical.py example")
#     115
# --> 116 show(row(dot, sizing_mode="scale_width"))
#
# TypeError: 'list' object is not callable

# %% [markdown]
# # Forecasts：

# %%
import csv
import pandas as pd
import scipy

# %%
df = pd.read_csv('Transform-Data/ForecastData.csv')
df
# Out:
#               Date  ActualCheckins  Predicted-MA  Predicted-Reg
# 0      1/1/10 0:00             650             0     812.515115
# 1      1/2/10 0:00            1028             0     641.811214
# 2      1/3/10 0:00             944             0    1131.799437
# 3      1/4/10 0:00            1086             0     981.261214
# 4      1/5/10 0:00            1071             0     850.613456
# 5      1/6/10 0:00            1498             0    1025.782802
# 6      1/7/10 0:00             977             0    1079.030033
# 7      1/8/10 0:00             899             0    1448.109028
# 8      1/9/10 0:00             801             0     924.140511
# 9     1/10/10 0:00            1020             0    1384.140412
# 10    1/11/10 0:00            1018             0    1030.908652
# 11    1/12/10 0:00             958             0     921.132923
# 12    1/13/10 0:00             800             0     921.122098
# 13    1/14/10 0:00            1151             0    1015.347514
# 14    1/15/10 0:00            1825             0    1638.160146
# 15    1/16/10 0:00             814             0     728.107363
# 16    1/17/10 0:00            1029             0    1272.681115
# 17    1/18/10 0:00            1457             0    1862.393691
# 18    1/19/10 0:00            1080             0     838.211926
# 19    1/20/10 0:00             634             0     907.990528
# 20    1/21/10 0:00             853             0     951.953426
# 21    1/22/10 0:00            1338          1125    1378.414937
# 22    1/23/10 0:00            1181           881     849.226773
# 23    1/24/10 0:00            1495           998    1510.641591
# 24    1/25/10 0:00             583          1187    1076.550932
# 25    1/26/10 0:00             740          1036     922.170017
# 26    1/27/10 0:00            1000           977     848.493971
# 27    1/28/10 0:00            1341           994    1077.896352
# 28    1/29/10 0:00            1381          1354    1466.499111
# 29    1/30/10 0:00             714           932     882.386747
# ...            ...             ...           ...            ...
# 1307  7/31/13 0:00             300           631     824.566080
# 1308   8/1/13 0:00             393           406    1114.180180
# 1309   8/2/13 0:00            1917          1791            NaN
# 1310   8/3/13 0:00            1067          1121            NaN
# 1311   8/4/13 0:00            1598          1505            NaN
# 1312   8/5/13 0:00            1343          1088            NaN
# 1313   8/6/13 0:00             949          1264            NaN
# 1314   8/7/13 0:00            1040           669            NaN
# 1315   8/8/13 0:00             519           453            NaN
# 1316   8/9/13 0:00            1531          1771            NaN
# 1317  8/10/13 0:00            1427          1016            NaN
# 1318  8/11/13 0:00            1430          1456            NaN
# 1319  8/12/13 0:00            1053          1015            NaN
# 1320  8/13/13 0:00            1124          1291            NaN
# 1321  8/14/13 0:00            1101           629            NaN
# 1322  8/15/13 0:00             610           451            NaN
# 1323  8/16/13 0:00            1845          1716            NaN
# 1324  8/17/13 0:00            1090           950            NaN
# 1325  8/18/13 0:00            2035          1450            NaN
# 1326  8/19/13 0:00             809           937            NaN
# 1327  8/20/13 0:00             450          1381            NaN
# 1328  8/21/13 0:00             478           533            NaN
# 1329  8/22/13 0:00             511           432            NaN
# 1330  8/23/13 0:00            1955          1759            NaN
# 1331  8/24/13 0:00            1001          1029            NaN
# 1332  8/25/13 0:00            1775          1470            NaN
# 1333  8/26/13 0:00            1068          1013            NaN
# 1334  8/27/13 0:00             769          1312            NaN
# 1335  8/28/13 0:00             887           610            NaN
# 1336  8/29/13 0:00             517           445            NaN
#
# [1337 rows x 4 columns]

# %% [markdown]
# # Prediction from Moving Average Method and the Actual values：

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/Images/Forecast-MovingAvg.png)

# %% [markdown]
# # Prediction from Regression Method and the Actual values：

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/Images/Forecast-Causal.png)

# %%
df.Date = pd.to_datetime(df['Date'], format='%m/%d/%y %H:%M')
df.set_index(['Date'],inplace=True)
df.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/Bose/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-840dd4082cca> in <module>()
# ----> 1 df.Date = pd.to_datetime(df['Date'], format='%m/%d/%y %H:%M')
#       2 df.set_index(['Date'],inplace=True)
#       3 df.plot()
#
# /Users/Bose/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Users/Bose/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /Users/Bose/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /Users/Bose/anaconda3/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/Bose/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'Date'

# %% [markdown]
# From the graph we can see that the regression model fits better than the moving average model.

# %% [markdown]
# Smaller MAPE for Regression and less Maximum error compared to Moving Average .

# %% [markdown]
# ![](https://github.com/bosea3000/Projects/raw/master/Caesars-Staffing-Problem/Images/MAPE.png)
